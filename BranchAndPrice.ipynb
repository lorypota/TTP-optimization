# %%
import numpy as np
import pandas as pd 
import gurobipy as gp
from gurobipy import GRB
from bs4 import BeautifulSoup
import lxml

# %%
with open('NL4.xml', 'r') as f:
    data = f.read()

# %%
Bs_data = BeautifulSoup(data, "xml")

# %%
Bs_data
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Instance>
# <MetaData>
# <InstanceName>NL4</InstanceName>
# <DataType>A</DataType>
# <Contributor>Easton, Nemhauser, and Trick</Contributor>
# <Date day="0" month="0" year="2001"/>
# <Country/>
# <Remarks>Based on National Hockey League</Remarks>
# <Lowerbound infeasibility="0" objective="0"/>
# </MetaData>
# <Structure>
# <Format leagueIds="0">
# <numberRoundRobin>2</numberRoundRobin>
# <compactness>C</compactness>
# </Format>
# <AdditionalGames/>
# </Structure>
# <ObjectiveFunction>
# <Objective>TR</Objective>
# </ObjectiveFunction>
# <Data>
# <Distances>
# <distance dist="0" team1="0" team2="0"/>
# <distance dist="745" team1="0" team2="1"/>
# <distance dist="665" team1="0" team2="2"/>
# <distance dist="929" team1="0" team2="3"/>
# <distance dist="745" team1="1" team2="0"/>
# <distance dist="0" team1="1" team2="1"/>
# <distance dist="80" team1="1" team2="2"/>
# <distance dist="337" team1="1" team2="3"/>
# <distance dist="665" team1="2" team2="0"/>
# <distance dist="80" team1="2" team2="1"/>
# <distance dist="0" team1="2" team2="2"/>
# <distance dist="380" team1="2" team2="3"/>
# <distance dist="929" team1="3" team2="0"/>
# <distance dist="337" team1="3" team2="1"/>
# <distance dist="380" team1="3" team2="2"/>
# <distance dist="0" team1="3" team2="3"/>
# </Distances>
# <COEWeights/>
# <Costs/>
# </Data>
# <Resources>
# <TeamGroups>
# <teamGroup id="0" name="All teams"/>
# </TeamGroups>
# <LeagueGroups/>
# <Leagues>
# <league id="0" name="League 0"/>
# </Leagues>
# <Teams>
# <team id="0" league="0" name="ATL" teamGroups="0"/>
# <team id="1" league="0" name="NYM" teamGroups="0"/>
# <team id="2" league="0" name="PHI" teamGroups="0"/>
# <team id="3" league="0" name="MON" teamGroups="0"/>
# </Teams>
# <SlotGroups/>
# <Slots>
# <slot id="0" name="Slot0"/>
# <slot id="1" name="Slot1"/>
# <slot id="2" name="Slot2"/>
# <slot id="3" name="Slot3"/>
# <slot id="4" name="Slot4"/>
# <slot id="5" name="Slot5"/>
# </Slots>
# </Resources>
# <Constraints>
# <BasicConstraints/>
# <CapacityConstraints>
# <CA3 intp="4" max="3" min="0" mode1="H" mode2="GAMES" penalty="1" teamGroups1="0" teamGroups2="0" type="HARD"/>
# <CA3 intp="4" max="3" min="0" mode1="A" mode2="GAMES" penalty="1" teamGroups1="0" teamGroups2="0" type="HARD"/>
# </CapacityConstraints>
# <GameConstraints/>
# <BreakConstraints/>
# <FairnessConstraints/>
# <SeparationConstraints>
# <SE1 max="6" min="1" penalty="1" teamGroups="0" type="HARD"/>
# </SeparationConstraints>
# </Constraints>
# </Instance>

# %%
raw_distance_entries = Bs_data.find_all("distance")
distances = []
team1nrs = []
team2nrs = []
for e in raw_distance_entries:
    print(e)
    distances.append(e.get("dist"))
    team1nrs.append(e.get("team1"))
    team2nrs.append(e.get("team2"))

DF = pd.DataFrame(np.array([distances, team1nrs, team2nrs]).T, columns = ["distance", "team1", "team2"])
# Out:
# <distance dist="0" team1="0" team2="0"/>
# <distance dist="745" team1="0" team2="1"/>
# <distance dist="665" team1="0" team2="2"/>
# <distance dist="929" team1="0" team2="3"/>
# <distance dist="745" team1="1" team2="0"/>
# <distance dist="0" team1="1" team2="1"/>
# <distance dist="80" team1="1" team2="2"/>
# <distance dist="337" team1="1" team2="3"/>
# <distance dist="665" team1="2" team2="0"/>
# <distance dist="80" team1="2" team2="1"/>
# <distance dist="0" team1="2" team2="2"/>
# <distance dist="380" team1="2" team2="3"/>
# <distance dist="929" team1="3" team2="0"/>
# <distance dist="337" team1="3" team2="1"/>
# <distance dist="380" team1="3" team2="2"/>
# <distance dist="0" team1="3" team2="3"/>

# %%
DF
# Out:
#    distance team1 team2
# 0         0     0     0
# 1       745     0     1
# 2       665     0     2
# 3       929     0     3
# 4       745     1     0
# 5         0     1     1
# 6        80     1     2
# 7       337     1     3
# 8       665     2     0
# 9        80     2     1
# 10        0     2     2
# 11      380     2     3
# 12      929     3     0
# 13      337     3     1
# 14      380     3     2
# 15        0     3     3

# %%
raw_team_entries = Bs_data.find_all("team")
team_dict = {}
for e in raw_team_entries:
    team_dict[e.get("id")] = e.get("name")
team_dict
# Out:
# {'0': 'ATL', '1': 'NYM', '2': 'PHI', '3': 'MON'}

# %%
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
from networkx.drawing.nx_agraph import to_agraph

# %%
arcs = list(DF[["team1", "team2"]].itertuples(index=False, name=None))

# %%
for i in range(DF.shape[0]):
    print(f"{DF["distance"][i]} - {DF["team1"][i]} - {DF["team2"][i]}")
# Out:
# 0 - 0 - 0
# 745 - 0 - 1
# 665 - 0 - 2
# 929 - 0 - 3
# 745 - 1 - 0
# 0 - 1 - 1
# 80 - 1 - 2
# 337 - 1 - 3
# 665 - 2 - 0
# 80 - 2 - 1
# 0 - 2 - 2
# 380 - 2 - 3
# 929 - 3 - 0
# 337 - 3 - 1
# 380 - 3 - 2
# 0 - 3 - 3

# %%
G = nx.MultiDiGraph()
for entry in team_dict:
    G.add_node(entry)

for i in range(DF.shape[0]):
    distance = int(DF["distance"][i])
    length = 0
    if int(distance) > 0:
        length = 1/int(distance)
    team1 = DF["team1"][i]
    team2 = DF["team2"][i]
    G.add_edge(team1, team2, weight=distance, length=length)

pos = nx.spring_layout(G)

nx.draw(G, pos=pos, with_labels=True, labels=team_dict, node_size = 1000)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, "weight"), verticalalignment="top")
# Out:
# {('0', '0', 0): Text(0.3102604913009266, 0.26042605533899343, '0'),
#  ('0', '1', 0): Text(0.4869386039942598, -0.34948851480513277, '745'),
#  ('0', '2', 0): Text(-0.02855713994055742, 0.5411503450478865, '665'),
#  ('0', '3', 0): Text(-0.1481220891693844, -0.10936625612329476, '929'),
#  ('1', '0', 0): Text(0.4869357293461942, -0.3494814893873829, '745'),
#  ('1', '1', 0): Text(0.6636138420395274, -0.6031422305257801, '0'),
#  ('1', '2', 0): Text(0.14811759801321378, 0.10936976306350643, '80'),
#  ('1', '3', 0): Text(0.028552974231055184, -0.5411482116076671, '337'),
#  ('2', '0', 0): Text(-0.02855599596081404, 0.5411487957882422, '665'),
#  ('2', '1', 0): Text(0.14812261682401584, 0.10936109190784893, '80'),
#  ('2', '2', 0): Text(-0.3673736272022979, 1.1781269145028637, '0'),
#  ('2', '3', 0): Text(-0.48693472975465624, 0.34949826073793355, '380'),
#  ('3', '0', 0): Text(-0.148118125667846, -0.1093645988480666, '929'),
#  ('3', '1', 0): Text(0.028560161670315387, -0.5411509292284679, '337'),
#  ('3', '2', 0): Text(-0.48693960358579863, 0.3494717434545753, '380'),
#  ('3', '3', 0): Text(-0.606500706138157, -0.12290308130462624, '0')}

# %% [markdown]
# ### Attempted implementation of IP formulation by Ribeiro 2011

# %%
import gurobipy as gp
from gurobipy import GRB
from collections import defaultdict

# %%
model = gp.Model("Ribeiro2011")

# %%
x = defaultdict(lambda: defaultdict(dict))
y = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))

nr_teams = len(team_dict)
nr_rounds = 2*(nr_teams - 1)


for i in (team_dict.values()):
    for j in (team_dict.values()):
        for k in range(nr_rounds):
            x[i, j, k] = model.addVar(name=f"x_{i}_{j}_{k}", vtype=GRB.BINARY)

for t in team_dict.values():
    for i in team_dict.values():
        for j in team_dict.values():
            for k in range(nr_rounds):
                y[t, i, j, k] = model.addVar(name=f"y_{t}_{i}_{j}_{k}", vtype=GRB.BINARY)

#TODO: Finalize implementation
#objective = gp.quicksum(gp.quicksum() for i in range(nr_teams))

# %%
DF["team1_name"] = [team_dict[x] for x in DF["team1"]]
DF["team2_name"] = [team_dict[x] for x in DF["team2"]]

# %%
d = defaultdict(lambda: defaultdict(dict))
for i in DF["team1_name"]:
    for j in DF["team2_name"]:
        d[i, j] = int(DF["distance"][(DF["team1_name"] == i) & (DF["team2_name"] == j)])
# Out:
# /tmp/ipykernel_14399/1985004505.py:4: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   d[i, j] = int(DF["distance"][(DF["team1_name"] == i) & (DF["team2_name"] == j)])

# %%
objective = gp.quicksum(gp.quicksum(d[i, j] * float(x[i, j, 1]) for j in range(nr_teams)) for i in range(nr_teams))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 objective = gp.quicksum(gp.quicksum(d[i, j] * float(x[i, j, 1]) for j in range(nr_teams)) for i in range(nr_teams))
#
# File src/gurobipy/_helpers.pyx:41, in gurobipy._helpers.quicksum()
#
# Cell In[134], line 1, in <genexpr>(.0)
# ----> 1 objective = gp.quicksum(gp.quicksum(d[i, j] * float(x[i, j, 1]) for j in range(nr_teams)) for i in range(nr_teams))
#
# File src/gurobipy/_helpers.pyx:41, in gurobipy._helpers.quicksum()
#
# Cell In[134], line 1, in <genexpr>(.0)
# ----> 1 objective = gp.quicksum(gp.quicksum(d[i, j] * float(x[i, j, 1]) for j in range(nr_teams)) for i in range(nr_teams))
#
# TypeError: float() argument must be a string or a real number, not 'collections.defaultdict'

# %% [markdown]
# #### Column generation testing

# %%
# TTP True Branch-and-Price Implementation

from itertools import product, combinations
import numpy as np
from copy import deepcopy
import time, math, heapq
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# ----------------------- USER INPUT -----------------------

team_names = []
dist_matrix = np.array([])

predefined_instance = "NL6"

if (predefined_instance == "NL4"):
    
    team_names = ["ATL","NYM","PHI","MON"]
    
    dist_matrix = np.array([
        [0, 665, 80, 380],
        [665, 0, 745, 929],
        [80, 745, 0, 337],
        [380, 929, 337, 0]
    ], dtype=float)

elif (predefined_instance == "NL6"):
    
    team_names = [
        "ATL",  # id=0
        "NYM",  # id=1
        "PHI",  # id=2
        "MON",  # id=3
        "FLA",  # id=4
        "PIT"   # id=5
    ]
    
    dist_matrix = np.array([
        #   ATL,   NYM,   PHI,   MON,   FLA,   PIT
        [    0,   745,   665,   929,   605,   521],  # ATL
        [  745,     0,    80,   337,  1090,   315],  # NYM
        [  665,    80,     0,   380,  1020,   257],  # PHI
        [  929,   337,   380,     0,  1380,   408],  # MON
        [  605,  1090,  1020,  1380,     0,  1010],  # FLA
        [  521,   315,   257,   408,  1010,     0]   # PIT
    ], dtype=float)
# ----------------------------------------------------------------

# Basic checks / preprocessing
if dist_matrix.shape[0] != dist_matrix.shape[1]:
    raise ValueError("Distance matrix must be square.")
if len(team_names) != dist_matrix.shape[0]:
    raise ValueError("Number of team names must equal matrix size.")

n = len(team_names)
m_slots = 2*(n-1)
pair_list = list(combinations(range(n), 2))
pair_to_idx = {pair:i for i,pair in enumerate(pair_list)}
P = len(pair_list)

print(f"Setup: n={n}, slots={m_slots}, pairs={P}")

# ----------------------- Pricing Subproblem Solver -----------------------

def solve_pricing_subproblem(team_idx, duals):
    """
    Solves the pricing subproblem for a single team using a shortest path algorithm
    on a state-space graph. This dynamically generates the tour with the
    minimum reduced cost. (Corrected Backtracking Logic)
    """
    opponents = [i for i in range(n) if i != team_idx]
    opp_map = {opp: i for i, opp in enumerate(opponents)}
    num_opp = len(opponents)

    # State: (slot, location, played_mask)
    # played_mask tuple: 0=not played, 1=played home, 2=played away, 3=played both
    source_node = (-1, team_idx, tuple([0] * num_opp))
    
    # DP table: labels[node] = (cost, predecessor_node, (opponent, is_home))
    # 'labels' will now accumulate all nodes, 'prev_labels' is for the current layer
    labels = {source_node: (0.0, None, None)}
    prev_labels = {source_node: (0.0, None, None)}

    for s in range(m_slots):
        next_labels = {}
        for node, (cost, _, _) in prev_labels.items():
            _, prev_loc, prev_mask = node
            
            for opp_team in opponents:
                opp_idx = opp_map[opp_team]
                
                possible_moves = []
                if prev_mask[opp_idx] == 0:
                    possible_moves.extend([(True, 1), (False, 2)])
                elif prev_mask[opp_idx] == 1:
                    possible_moves.append((False, 3))
                elif prev_mask[opp_idx] == 2:
                    possible_moves.append((True, 3))
                
                for is_home, new_mask_val in possible_moves:
                    venue = team_idx if is_home else opp_team
                    
                    new_mask = list(prev_mask)
                    new_mask[opp_idx] = new_mask_val
                    arc_cost = dist_matrix[prev_loc, venue]
                    
                    i, j = (team_idx, opp_team) if team_idx < opp_team else (opp_team, team_idx)
                    pair_idx = pair_to_idx[(i,j)]
                    relative_constr_idx = pair_idx * m_slots + s

                    if s == 0: arc_cost -= duals['team'][team_idx]
                    
                    sign = 1.0 if team_idx == i else -1.0
                    arc_cost -= sign * duals['pair_slot'][relative_constr_idx]

                    hf = 1.0 if is_home else 0.0
                    if team_idx == i:
                        arc_cost -= (hf - 1.0) * duals['home_cons'][relative_constr_idx]
                    else:
                        arc_cost -= hf * duals['home_cons'][relative_constr_idx]

                    new_node = (s, venue, tuple(new_mask))
                    new_cost = cost + arc_cost
                    if new_node not in next_labels or new_cost < next_labels[new_node][0]:
                        next_labels[new_node] = (new_cost, node, (opp_team, is_home))
        
        # --- BUG FIX IS HERE ---
        # Update the main labels dictionary and set the next layer to expand
        if not next_labels: # No path forward from this layer
            break
        labels.update(next_labels)
        prev_labels = next_labels

    # Find the best final node and add the cost of returning home
    best_final_node = None
    min_rc = 0.0
    final_mask = tuple([3] * num_opp)
    
    # Search for a valid final node in the last populated layer
    last_slot = max([node[0] for node in labels.keys()])
    if last_slot == m_slots - 1:
        for node, (cost, _, _) in labels.items():
            s_node, loc, mask = node
            if s_node == m_slots - 1 and mask == final_mask:
                final_cost = cost + dist_matrix[loc, team_idx]
                if final_cost < min_rc:
                    min_rc = final_cost
                    best_final_node = node
    
    if min_rc < -1e-6:
        tour = {'opp_seq': [0]*m_slots, 'home_flags': [False]*m_slots}
        curr = best_final_node
        while curr != source_node:
            s, _, _ = curr
            _, pred, (opp, is_home) = labels[curr] # This lookup will now succeed
            tour['opp_seq'][s] = opp
            tour['home_flags'][s] = is_home
            curr = pred

        def compute_true_cost(t_idx, opp_seq, home_flags):
            cost = 0.0
            prev = t_idx
            for s_idx, opp in enumerate(opp_seq):
                venue = t_idx if home_flags[s_idx] else opp
                cost += dist_matrix[prev, venue]
                prev = venue
            cost += dist_matrix[prev, t_idx]
            return cost
        
        tour['cost'] = compute_true_cost(team_idx, tour['opp_seq'], tour['home_flags'])
        tour['delta'] = np.zeros((n, m_slots), dtype=int)
        for s, opp in enumerate(tour['opp_seq']):
            tour['delta'][opp, s] = 1
        return tour
        
    return None
# ----------------------- Column Generation (Modified) -----------------------
def column_generation_gurobi(node_pool, forbid_triplets=None, forbid_signatures=None, require_list=None, cg_max_iters=500, tol=1e-9):
    pool = deepcopy(node_pool)
    it = 0
    while it < cg_max_iters:
        it += 1
        model, xvars, included_cols, constrs = build_master_model_gurobi(pool,
            forbid_triplets=forbid_triplets, forbid_signatures=forbid_signatures, require_list=require_list)
        model.optimize()

        if model.Status != GRB.OPTIMAL:
            print(f"Gurobi master problem not optimal (Status: {model.Status}). Node might be infeasible.")
            return None, None, None, None, None

        # Re-organize duals for easy access in pricing subproblem
        all_duals = np.array([c.Pi for c in constrs])
        duals = {
            'team': all_duals[0:n],
            'pair_slot': all_duals[n : n + P*m_slots],
            'home_cons': all_duals[n + P*m_slots : n + 2*P*m_slots],
            'require': all_duals[n + 2*P*m_slots:]
        }

        to_add = []
        for t in range(n):
            # *** THE KEY CHANGE IS HERE ***
            # Instead of iterating a list, we call the dynamic solver
            new_tour = solve_pricing_subproblem(t, duals)
            
            if new_tour:
                # Check if this tour signature is already in the pool
                sig = (t, tuple(new_tour['opp_seq']), tuple(new_tour['home_flags']))
                is_present = any(
                    (col['team'], tuple(col['tour']['opp_seq']), tuple(col['tour']['home_flags'])) == sig
                    for col in pool
                )
                if not is_present:
                    to_add.append({'team': t, 'tour': new_tour})

        if not to_add:
            x_vals = np.array([v.X for v in xvars])
            return model, xvars, included_cols, x_vals, model.ObjVal

        for col in to_add:
            pool.append(col)

    print("CG reached max iterations.")
    # Final solve
    model, xvars, included_cols, constrs = build_master_model_gurobi(pool,
        forbid_triplets=forbid_triplets, forbid_signatures=forbid_signatures, require_list=require_list)
    model.optimize()
    if model.Status != GRB.OPTIMAL: return None, None, None, None, None
    x_vals = np.array([v.X for v in xvars])
    return model, xvars, included_cols, x_vals, model.ObjVal

# ============================================================================================
#  The rest of the script (Master Problem Builder, Branching, etc.) remains the same.
#  I am including it here for a complete, runnable file.
# ============================================================================================

def compute_tour_cost(team_idx, opp_seq, home_flags, dist=dist_matrix):
    cost = 0.0
    prev = team_idx
    for s_idx, opp in enumerate(opp_seq):
        venue = team_idx if home_flags[s_idx] else opp
        cost += dist[prev, venue]
        prev = venue
    cost += dist[prev, team_idx]
    return float(cost)

def circle_method_pairings(n):
    assert n % 2 == 0
    teams_idx = list(range(n))
    fixed = teams_idx[-1]
    rot = teams_idx[:-1]
    rounds = []
    for r in range(n-1):
        pairs = []
        pairs.append(tuple(sorted((rot[0], fixed))))
        for k in range(1, n//2):
            i = rot[k]; j = rot[-k]
            pairs.append(tuple(sorted((i,j))))
        rounds.append(pairs)
        rot = [rot[-1]] + rot[:-1]
    return rounds + deepcopy(rounds)

def schedule_to_tours(pairings):
    schedule_opp = np.full((m_slots, n), -1, dtype=int)
    schedule_home = np.zeros((m_slots, n), dtype=bool)
    for s in range(m_slots):
        pairs = pairings[s]
        for (i,j) in pairs:
            if s < (n-1):
                schedule_opp[s,i] = j; schedule_home[s,i] = True
                schedule_opp[s,j] = i; schedule_home[s,j] = False
            else:
                schedule_opp[s,i] = j; schedule_home[s,i] = False
                schedule_opp[s,j] = i; schedule_home[s,j] = True
    tours = []
    for t in range(n):
        opp_seq = list(schedule_opp[:, t])
        home_flags = list(schedule_home[:, t])
        delta = np.zeros((n, m_slots), dtype=int)
        for s_idx, opp in enumerate(opp_seq): delta[opp, s_idx] = 1
        cost = compute_tour_cost(t, opp_seq, home_flags)
        tours.append({'opp_seq': opp_seq, 'home_flags': home_flags, 'delta': delta, 'cost': cost})
    return schedule_opp, schedule_home, tours

def build_master_model_gurobi(pool, forbid_triplets=None, forbid_signatures=None, require_list=None, gurobi_params=None):
    if forbid_triplets is None: forbid_triplets = set()
    if forbid_signatures is None: forbid_signatures = set()
    if require_list is None: require_list = []

    included_cols = []
    for col in pool:
        t = col['team']; tour = col['tour']
        sig = (t, tuple(tour['opp_seq']), tuple(tour['home_flags']))
        if sig in forbid_signatures: continue
        bad = False
        for s, opp in enumerate(tour['opp_seq']):
            if (t, opp, s) in forbid_triplets:
                bad = True; break
        if bad: continue
        included_cols.append(col)

    model = gp.Model("TTP_Master")
    model.Params.OutputFlag = 0
    if gurobi_params:
        for k,v in gurobi_params.items(): setattr(model.Params, k, v)

    xvars = model.addVars(len(included_cols), lb=0.0, obj=[float(c['tour']['cost']) for c in included_cols], name="x")
    model.update()

    constrs = []
    # 1) team coverage rows
    for t in range(n):
        expr = gp.LinExpr([(1.0, xvars[k]) for k, col in enumerate(included_cols) if col['team'] == t])
        constrs.append(model.addConstr(expr == 1.0, name=f"team_{t}"))

    # 2) pair-slot signed equality rows
    for pair_idx, (i,j) in enumerate(pair_list):
        for s in range(m_slots):
            expr = gp.LinExpr()
            for k, col in enumerate(included_cols):
                t = col['team']; tour = col['tour']
                if t == i and tour['delta'][j, s] == 1: expr += xvars[k]
                elif t == j and tour['delta'][i, s] == 1: expr += -xvars[k]
            constrs.append(model.addConstr(expr == 0.0, name=f"pair_{i}_{j}_slot_{s}"))

    # 3) home-consistency rows
    for pair_idx, (i,j) in enumerate(pair_list):
        for s in range(m_slots):
            expr = gp.LinExpr()
            for k, col in enumerate(included_cols):
                t = col['team']; tour = col['tour']
                if t == i and tour['opp_seq'][s] == j:
                    hf = 1.0 if tour['home_flags'][s] else 0.0
                    expr += (hf - 1.0) * xvars[k]
                elif t == j and tour['opp_seq'][s] == i:
                    hf = 1.0 if tour['home_flags'][s] else 0.0
                    expr += hf * xvars[k]
            constrs.append(model.addConstr(expr == 0.0, name=f"home_{i}_{j}_slot_{s}"))

    # 4) require rows
    for idx_req, (i,j,s) in enumerate(require_list):
        expr = gp.LinExpr([(1.0, xvars[k]) for k, col in enumerate(included_cols) if col['team'] == i and col['tour']['delta'][j, s] == 1])
        constrs.append(model.addConstr(expr == 1.0, name=f"require_{i}_{j}_{s}"))

    model.ModelSense = GRB.MINIMIZE
    model.update()
    return model, list(xvars.values()), included_cols, constrs

def compute_pairslot_z_from_solution(included_cols, x_vals):
    zvals = {}
    for pair_idx, (i,j) in enumerate(pair_list):
        for s in range(m_slots):
            z = sum(x_vals[k] for k, col in enumerate(included_cols) if col['team'] == i and col['tour']['delta'][j,s] == 1)
            zvals[(i,j,s)] = z
    return zvals

def is_solution_integral(x_vals, tol=1e-6):
    return all(abs(v - round(v)) < tol for v in x_vals)

def branch_and_price_gurobi(initial_pool, time_limit_nodes=36000.0, max_nodes=2000):
    start_time = time.time()
    node_id_gen = 0
    heap = []
    heapq.heappush(heap, (0.0, node_id_gen, initial_pool, frozenset(), frozenset(), tuple()))
    node_id_gen += 1
    best_int_obj = math.inf
    best_int_solution = None
    nodes_processed = 0

    while heap and (time.time() - start_time) < time_limit_nodes and nodes_processed < max_nodes:
        lb, node_id, node_pool, forbid_triplets, forbid_signatures, require_list = heapq.heappop(heap)
        if lb >= best_int_obj: continue
        nodes_processed += 1
        print(f"\nNode {node_id} (processed {nodes_processed}) lb={lb:.2f} |B_T|={len(forbid_triplets)} |B_S|={len(forbid_signatures)} |R|={len(require_list)}")
        
        current_pool = [col for col in node_pool]
        
        # --- BUG FIX IS HERE ---
        # Unpack the result first, then check for failure.
        res = column_generation_gurobi(current_pool, set(forbid_triplets), set(forbid_signatures), list(require_list))
        model, xvars, included_cols, x_vals, obj = res
        
        # Now, check if the run was successful. A None model indicates failure.
        if model is None:
            print(" -> Node LP infeasible, prune.")
            continue
        
        print(f" -> Node LP obj = {obj:.2f}, columns = {len(included_cols)}")
        if obj >= best_int_obj - 1e-9:
            print(" -> Bound >= incumbent, prune.")
            continue

        if is_solution_integral(x_vals):
            print(f" -> Integer solution found with obj = {obj:.2f}!")
            if obj < best_int_obj:
                best_int_obj = obj
                best_int_solution = [col for k, col in enumerate(included_cols) if x_vals[k] > 0.5]
                heap = [(p_lb, p_id, p_pool, p_ft, p_fs, p_req) for p_lb, p_id, p_pool, p_ft, p_fs, p_req in heap if p_lb < best_int_obj]
                heapq.heapify(heap)
            continue

        zvals = compute_pairslot_z_from_solution(included_cols, x_vals)
        frac_items = sorted([(abs(val - 0.5), (pair, val)) for pair, val in zvals.items() if 1e-6 < val < 1 - 1e-6])
        if frac_items:
            _, ((i,j,s), val) = frac_items[0]
            print(f" -> Branch on pair-slot z({i},{j},{s}) = {val:.4f}")
            child1_require = tuple(list(require_list) + [(i,j,s)])
            heapq.heappush(heap, (obj, node_id_gen, included_cols, forbid_triplets, forbid_signatures, child1_require)); node_id_gen += 1
            child2_trip = set(forbid_triplets); child2_trip.add((i,j,s)); child2_trip.add((j,i,s))
            heapq.heappush(heap, (obj, node_id_gen, included_cols, frozenset(child2_trip), forbid_signatures, require_list)); node_id_gen += 1
        else:
            frac_cols = [(k, x_vals[k]) for k, v in enumerate(x_vals) if 1e-6 < v < 1-1e-6]
            if not frac_cols:
                print(" -> Z and X are integral, but check failed. Pruning.")
                continue
            by_team = {}
            for k, val in frac_cols: by_team.setdefault(included_cols[k]['team'], []).append((val, k))
            target_team = max(by_team, key=lambda t: sum(v for v,k in by_team[t]))
            _, k_to_forbid = max(by_team[target_team])
            col_to_forbid = included_cols[k_to_forbid]
            sig_to_forbid = (col_to_forbid['team'], tuple(col_to_forbid['tour']['opp_seq']), tuple(col_to_forbid['tour']['home_flags']))
            print(f" -> Fallback branch on fractional tour for team {team_names[target_team]} (x_{k_to_forbid}={x_vals[k_to_forbid]:.4f})")
            child1_sigs = set(forbid_signatures); child1_sigs.add(sig_to_forbid)
            heapq.heappush(heap, (obj, node_id_gen, included_cols, forbid_triplets, frozenset(child1_sigs), require_list)); node_id_gen += 1
            other_frac_cols = [c for c in by_team[target_team] if c[1] != k_to_forbid]
            if other_frac_cols:
                _, k2_to_forbid = max(other_frac_cols)
                col2_to_forbid = included_cols[k2_to_forbid]
                sig2_to_forbid = (col2_to_forbid['team'], tuple(col2_to_forbid['tour']['opp_seq']), tuple(col2_to_forbid['tour']['home_flags']))
                child2_sigs = set(forbid_signatures); child2_sigs.add(sig2_to_forbid)
                heapq.heappush(heap, (obj, node_id_gen, included_cols, forbid_triplets, frozenset(child2_sigs), require_list)); node_id_gen += 1

    print(f"\nBranch-and-price finished. Nodes processed: {nodes_processed}")
    if best_int_solution is None:
        print("No integer solution found within limits.")
    else:
        print(f"Best integer obj = {best_int_obj:.2f}")
    return best_int_obj, best_int_solution

# ----------------------- Main Execution -----------------------
if __name__ == "__main__":
    # Prepare a basic initial pool of columns
    pairings = circle_method_pairings(n)
    _, _, initial_tours = schedule_to_tours(pairings)
    initial_pool = [{'team': t, 'tour': tour} for t, tour in enumerate(initial_tours)]
    print(f"Initial pool size: {len(initial_pool)}")
    
    start_total = time.time()
    best_obj, best_solution = branch_and_price_gurobi(initial_pool, time_limit_nodes=36000.0, max_nodes=2000)
    print(f"\nTotal elapsed time: {time.time() - start_total:.2f} seconds")

    if best_solution is not None:
        sel = []
        for col in sorted(best_solution, key=lambda c: c['team']):
            t = col['team']; tour = col['tour']
            sel.append({
                'team': team_names[t], 'cost': tour['cost'],
                'opp_seq': tuple(team_names[o] for o in tour['opp_seq']),
                'home_flags': tuple(['H' if h else 'A' for h in tour['home_flags']])
            })
        df = pd.DataFrame(sel)
        print("\nBest integer solution found:\n")
        print(df.to_string(index=False))
    else:
        print("\nNo integer solution was found.")
# Out:
# Setup: n=6, slots=10, pairs=15
# Initial pool size: 6
#
# Node 0 (processed 1) lb=0.00 |B_T|=0 |B_S|=0 |R|=0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 451
#     448 print(f"Initial pool size: {len(initial_pool)}")
#     450 start_total = time.time()
# --> 451 best_obj, best_solution = branch_and_price_gurobi(initial_pool, time_limit_nodes=36000.0, max_nodes=2000)
#     452 print(f"\nTotal elapsed time: {time.time() - start_total:.2f} seconds")
#     454 if best_solution is not None:
#
# Cell In[15], line 382, in branch_and_price_gurobi(initial_pool, time_limit_nodes, max_nodes)
#     378 current_pool = [col for col in node_pool]
#     380 # --- BUG FIX IS HERE ---
#     381 # Unpack the result first, then check for failure.
# --> 382 res = column_generation_gurobi(current_pool, set(forbid_triplets), set(forbid_signatures), list(require_list))
#     383 model, xvars, included_cols, x_vals, obj = res
#     385 # Now, check if the run was successful. A None model indicates failure.
#
# Cell In[15], line 206, in column_generation_gurobi(node_pool, forbid_triplets, forbid_signatures, require_list, cg_max_iters, tol)
#     202 to_add = []
#     203 for t in range(n):
#     204     # *** THE KEY CHANGE IS HERE ***
#     205     # Instead of iterating a list, we call the dynamic solver
# --> 206     new_tour = solve_pricing_subproblem(t, duals)
#     208     if new_tour:
#     209         # Check if this tour signature is already in the pool
#     210         sig = (t, tuple(new_tour['opp_seq']), tuple(new_tour['home_flags']))
#
# Cell In[15], line 127, in solve_pricing_subproblem(team_idx, duals)
#     125             new_cost = cost + arc_cost
#     126             if new_node not in next_labels or new_cost < next_labels[new_node][0]:
# --> 127                 next_labels[new_node] = (new_cost, node, (opp_team, is_home))
#     129 # --- BUG FIX IS HERE ---
#     130 # Update the main labels dictionary and set the next layer to expand
#     131 if not next_labels: # No path forward from this layer
#
# KeyboardInterrupt:

# %%
# TTP True Branch-and-Price with Full Constraints (No-Repeater, Consecutive H/A)

from itertools import product, combinations
import numpy as np
from copy import deepcopy
import time, math, heapq
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# ----------------------- USER INPUT -----------------------
predefined_instance = "NL6"

if predefined_instance == "NL4":
    team_names = ["ATL", "NYM", "PHI", "MON"]
    dist_matrix = np.array([
        [0, 665, 80, 380],
        [665, 0, 745, 929],
        [80, 745, 0, 337],
        [380, 929, 337, 0]
    ], dtype=float)
elif predefined_instance == "NL6":
    team_names = ["ATL", "NYM", "PHI", "MON", "FLA", "PIT"]
    dist_matrix = np.array([
        [0, 745, 665, 929, 605, 521],
        [745, 0, 80, 337, 1090, 315],
        [665, 80, 0, 380, 1020, 257],
        [929, 337, 380, 0, 1380, 408],
        [605, 1090, 1020, 1380, 0, 1010],
        [521, 315, 257, 408, 1010, 0]
    ], dtype=float)
# ----------------------------------------------------------------

# Basic checks / preprocessing
n = len(team_names)
m_slots = 2 * (n - 1)
pair_list = list(combinations(range(n), 2))
pair_to_idx = {pair: i for i, pair in enumerate(pair_list)}
P = len(pair_list)
print(f"Setup: n={n}, slots={m_slots}, pairs={P}")
print(f"Solving for {predefined_instance} instance.")

# ----------------------- Pricing Subproblem Solver (Enhanced for Constraints) -----------------------
def solve_pricing_subproblem(team_idx, duals, initial_generation=False):
    """
    Solves the pricing subproblem with constraints. Has a special mode for
    generating the initial pool where negative reduced cost is not required.
    """
    opponents = [i for i in range(n) if i != team_idx]
    opp_map = {opp: i for i, opp in enumerate(opponents)}
    num_opp = len(opponents)

    source_node = (-1, team_idx, tuple([0] * num_opp), -1, 0)
    labels = {source_node: (0.0, None, None)}
    prev_labels = {source_node: (0.0, None, None)}

    for s in range(m_slots):
        next_labels = {}
        for node, (cost, _, _) in prev_labels.items():
            _, prev_loc, prev_mask, prev_opp, prev_streak = node
            for opp_team in opponents:
                if opp_team == prev_opp: continue

                opp_idx = opp_map[opp_team]
                possible_moves = []
                if prev_mask[opp_idx] == 0:
                    possible_moves.extend([(True, 1), (False, 2)])
                elif prev_mask[opp_idx] == 1:
                    possible_moves.append((False, 3))
                elif prev_mask[opp_idx] == 2:
                    possible_moves.append((True, 3))

                for is_home, new_mask_val in possible_moves:
                    if (is_home and prev_streak == 3) or (not is_home and prev_streak == -3):
                        continue
                    
                    new_streak = (prev_streak + 1) if prev_streak > 0 else 1 if is_home else (prev_streak - 1) if prev_streak < 0 else -1
                    venue = team_idx if is_home else opp_team
                    new_mask = list(prev_mask); new_mask[opp_idx] = new_mask_val
                    arc_cost = dist_matrix[prev_loc, venue]

                    i, j = (team_idx, opp_team) if team_idx < opp_team else (opp_team, team_idx)
                    pair_idx = pair_to_idx[(i, j)]
                    relative_constr_idx = pair_idx * m_slots + s

                    if s == 0: arc_cost -= duals['team'][team_idx]
                    sign = 1.0 if team_idx == i else -1.0
                    arc_cost -= sign * duals['pair_slot'][relative_constr_idx]
                    hf = 1.0 if is_home else 0.0
                    if team_idx == i:
                        arc_cost -= (hf - 1.0) * duals['home_cons'][relative_constr_idx]
                    else:
                        arc_cost -= hf * duals['home_cons'][relative_constr_idx]

                    new_node = (s, venue, tuple(new_mask), opp_team, new_streak)
                    new_cost = cost + arc_cost
                    if new_node not in next_labels or new_cost < next_labels[new_node][0]:
                        next_labels[new_node] = (new_cost, node, (opp_team, is_home))
        
        if not next_labels: break
        labels.update(next_labels)
        prev_labels = next_labels

    best_final_node = None
    min_rc = float('inf') # Initialize with infinity to find the minimum cost tour
    final_mask = tuple([3] * num_opp)
    
    last_slot = max([node[0] for node in labels.keys()] or [-1])
    if last_slot == m_slots - 1:
        for node, (cost, _, _) in labels.items():
            s_node, loc, mask, _, _ = node
            if s_node == m_slots - 1 and mask == final_mask:
                final_cost = cost + dist_matrix[loc, team_idx]
                if final_cost < min_rc:
                    min_rc = final_cost
                    best_final_node = node
    
    # <<< BUG FIX: Return the best tour if in initial_generation mode,
    # or if the reduced cost is negative. >>>
    if best_final_node is not None and (initial_generation or min_rc < -1e-6):
        tour = {'opp_seq': [0]*m_slots, 'home_flags': [False]*m_slots}
        curr = best_final_node
        while curr != source_node:
            s, _, _, _, _ = curr
            _, pred, (opp, is_home) = labels[curr]
            tour['opp_seq'][s] = opp
            tour['home_flags'][s] = is_home
            curr = pred
        
        def compute_true_cost(t_idx, opp_seq, home_flags):
            cost = 0.0; prev = t_idx
            for s_idx, opp in enumerate(opp_seq):
                venue = t_idx if home_flags[s_idx] else opp
                cost += dist_matrix[prev, venue]; prev = venue
            cost += dist_matrix[prev, t_idx]
            return cost
        
        tour['cost'] = compute_true_cost(team_idx, tour['opp_seq'], tour['home_flags'])
        tour['delta'] = np.zeros((n, m_slots), dtype=int)
        for s, opp in enumerate(tour['opp_seq']):
            tour['delta'][opp, s] = 1
        return tour
        
    return None
    
# ============================================================================================
#  The rest of the script remains unchanged as it correctly handles validly generated tours.
# ============================================================================================

def column_generation_gurobi(node_pool, forbid_triplets=None, forbid_signatures=None, require_list=None, cg_max_iters=500, tol=1e-9):
    pool = deepcopy(node_pool)
    it = 0
    while it < cg_max_iters:
        it += 1
        model, xvars, included_cols, constrs = build_master_model_gurobi(pool,
            forbid_triplets=forbid_triplets, forbid_signatures=forbid_signatures, require_list=require_list)
        model.optimize()

        if model.Status != GRB.OPTIMAL:
            # print(f"Gurobi master problem not optimal (Status: {model.Status}).")
            return None, None, None, None, None

        all_duals = np.array([c.Pi for c in constrs])
        duals = {
            'team': all_duals[0:n],
            'pair_slot': all_duals[n : n + P*m_slots],
            'home_cons': all_duals[n + P*m_slots : n + 2*P*m_slots],
            'require': all_duals[n + 2*P*m_slots:]
        }

        to_add = []
        for t in range(n):
            new_tour = solve_pricing_subproblem(t, duals)
            if new_tour:
                sig = (t, tuple(new_tour['opp_seq']), tuple(new_tour['home_flags']))
                is_present = any(
                    (col['team'], tuple(col['tour']['opp_seq']), tuple(col['tour']['home_flags'])) == sig
                    for col in pool
                )
                if not is_present:
                    to_add.append({'team': t, 'tour': new_tour})

        if not to_add:
            x_vals = np.array([v.X for v in xvars])
            return model, xvars, included_cols, x_vals, model.ObjVal

        for col in to_add:
            pool.append(col)

    print("CG reached max iterations.")
    model, xvars, included_cols, constrs = build_master_model_gurobi(pool,
        forbid_triplets=forbid_triplets, forbid_signatures=forbid_signatures, require_list=require_list)
    model.optimize()
    if model.Status != GRB.OPTIMAL: return None, None, None, None, None
    x_vals = np.array([v.X for v in xvars])
    return model, xvars, included_cols, x_vals, model.ObjVal

def compute_tour_cost(team_idx, opp_seq, home_flags, dist=dist_matrix):
    cost = 0.0; prev = team_idx
    for s_idx, opp in enumerate(opp_seq):
        venue = team_idx if home_flags[s_idx] else opp
        cost += dist[prev, venue]
        prev = venue
    cost += dist[prev, team_idx]
    return float(cost)

def circle_method_pairings(n):
    assert n % 2 == 0
    teams_idx = list(range(n)); fixed = teams_idx[-1]; rot = teams_idx[:-1]
    rounds = []
    for r in range(n-1):
        pairs = [tuple(sorted((rot[0], fixed)))]
        for k in range(1, n//2):
            i = rot[k]; j = rot[-k]
            pairs.append(tuple(sorted((i,j))))
        rounds.append(pairs)
        rot = [rot[-1]] + rot[:-1]
    return rounds + deepcopy(rounds)

def schedule_to_tours(pairings):
    schedule_opp = np.full((m_slots, n), -1, dtype=int)
    schedule_home = np.zeros((m_slots, n), dtype=bool)
    for s in range(m_slots):
        for (i,j) in pairings[s]:
            if s < (n-1):
                schedule_opp[s,i] = j; schedule_home[s,i] = True
                schedule_opp[s,j] = i; schedule_home[s,j] = False
            else:
                schedule_opp[s,i] = j; schedule_home[s,i] = False
                schedule_opp[s,j] = i; schedule_home[s,j] = True
    tours = []
    for t in range(n):
        opp_seq = list(schedule_opp[:, t])
        home_flags = list(schedule_home[:, t])
        delta = np.zeros((n, m_slots), dtype=int)
        for s_idx, opp in enumerate(opp_seq): delta[opp, s_idx] = 1
        cost = compute_tour_cost(t, opp_seq, home_flags)
        tours.append({'opp_seq': opp_seq, 'home_flags': home_flags, 'delta': delta, 'cost': cost})
    return schedule_opp, schedule_home, tours

def build_master_model_gurobi(pool, forbid_triplets=None, forbid_signatures=None, require_list=None):
    if forbid_triplets is None: forbid_triplets = set()
    if forbid_signatures is None: forbid_signatures = set()
    if require_list is None: require_list = []
    included_cols = []
    for col in pool:
        t, tour = col['team'], col['tour']
        sig = (t, tuple(tour['opp_seq']), tuple(tour['home_flags']))
        if sig in forbid_signatures: continue
        if any((t, opp, s) in forbid_triplets for s, opp in enumerate(tour['opp_seq'])): continue
        included_cols.append(col)

    model = gp.Model("TTP_Master")
    model.Params.OutputFlag = 0
    
    # <<< ENHANCEMENT: Define a large penalty for artificial variables >>>
    M_PENALTY = 1e6

    xvars = model.addVars(len(included_cols), lb=0.0, obj=[float(c['tour']['cost']) for c in included_cols], name="x")
    model.update()
    constrs = []
    
    # 1) team coverage rows (These are "hard" constraints, no artificial variables)
    for t in range(n):
        expr = gp.LinExpr([(1.0, xvars[k]) for k, col in enumerate(included_cols) if col['team'] == t])
        constrs.append(model.addConstr(expr == 1.0, name=f"team_{t}"))

    # 2) pair-slot signed equality rows
    for pair_idx, (i,j) in enumerate(pair_list):
        for s in range(m_slots):
            expr = gp.LinExpr()
            for k, col in enumerate(included_cols):
                t, tour = col['team'], col['tour']
                if t == i and tour['delta'][j, s] == 1: expr += xvars[k]
                elif t == j and tour['delta'][i, s] == 1: expr += -xvars[k]
            
            # <<< ARTIFICIAL VARIABLES to ensure feasibility >>>
            s_plus = model.addVar(lb=0.0, obj=M_PENALTY, name=f"s_plus_pair_{i}_{j}_{s}")
            s_minus = model.addVar(lb=0.0, obj=M_PENALTY, name=f"s_minus_pair_{i}_{j}_{s}")
            constrs.append(model.addConstr(expr - s_plus + s_minus == 0.0, name=f"pair_{i}_{j}_slot_{s}"))

    # 3) home-consistency rows
    for pair_idx, (i,j) in enumerate(pair_list):
        for s in range(m_slots):
            expr = gp.LinExpr()
            for k, col in enumerate(included_cols):
                t, tour = col['team'], col['tour']
                if t == i and tour['opp_seq'][s] == j:
                    expr += (1.0 if tour['home_flags'][s] else 0.0 - 1.0) * xvars[k]
                elif t == j and tour['opp_seq'][s] == i:
                    expr += (1.0 if tour['home_flags'][s] else 0.0) * xvars[k]

            # <<< ARTIFICIAL VARIABLES to ensure feasibility >>>
            s_plus_h = model.addVar(lb=0.0, obj=M_PENALTY, name=f"s_plus_home_{i}_{j}_{s}")
            s_minus_h = model.addVar(lb=0.0, obj=M_PENALTY, name=f"s_minus_home_{i}_{j}_{s}")
            constrs.append(model.addConstr(expr - s_plus_h + s_minus_h == 0.0, name=f"home_{i}_{j}_slot_{s}"))

    # 4) require rows (Hard constraints)
    for i,j,s in require_list:
        expr = gp.LinExpr([(1.0, xvars[k]) for k, col in enumerate(included_cols) if col['team'] == i and col['tour']['delta'][j, s] == 1])
        constrs.append(model.addConstr(expr == 1.0, name=f"require_{i}_{j}_{s}"))
        
    model.ModelSense = GRB.MINIMIZE
    model.update()
    return model, list(xvars.values()), included_cols, constrs

def compute_pairslot_z_from_solution(included_cols, x_vals):
    zvals = {}
    for pair_idx, (i,j) in enumerate(pair_list):
        for s in range(m_slots):
            z = sum(x_vals[k] for k, col in enumerate(included_cols) if col['team'] == i and col['tour']['delta'][j,s] == 1)
            zvals[(i,j,s)] = z
    return zvals

def is_solution_integral(x_vals, tol=1e-6):
    return all(abs(v - round(v)) < tol for v in x_vals)

def branch_and_price_gurobi(initial_pool, time_limit_nodes=36000.0, max_nodes=2000):
    start_time = time.time()
    node_id_gen = 0
    heap = []
    heapq.heappush(heap, (0.0, node_id_gen, initial_pool, frozenset(), frozenset(), tuple()))
    node_id_gen += 1
    best_int_obj = float('inf')
    best_int_solution = None
    nodes_processed = 0

    while heap and (time.time() - start_time) < time_limit_nodes and nodes_processed < max_nodes:
        lb, node_id, node_pool, forbid_triplets, forbid_signatures, require_list = heapq.heappop(heap)
        
        # Prune if the node's lower bound is already worse than our best real solution
        if lb >= best_int_obj:
            continue
            
        nodes_processed += 1
        print(f"\nNode {node_id} (processed {nodes_processed}) lb={lb:.2f} |B_T|={len(forbid_triplets)} |B_S|={len(forbid_signatures)} |R|={len(require_list)}")
        
        res = column_generation_gurobi(list(node_pool), set(forbid_triplets), set(forbid_signatures), list(require_list))
        model, xvars, included_cols, x_vals, obj = res
        if model is None:
            print(" -> Node LP infeasible, prune.")
            continue
        
        # The LP objective 'obj' includes penalties, so it's only a valid lower bound
        print(f" -> Node LP obj (lower bound) = {obj:.2f}, columns = {len(included_cols)}")
        if obj >= best_int_obj:
            print(" -> Bound >= incumbent, prune.")
            continue

        if is_solution_integral(x_vals):
            solution_cols = [col for k, col in enumerate(included_cols) if x_vals[k] > 0.5]
            
            # <<< BUG FIX: Calculate the TRUE cost of the integer solution, ignoring penalties >>>
            true_obj = sum(col['tour']['cost'] for col in solution_cols)
            print(f" -> Integer solution found with TRUE cost = {true_obj:.2f}!")

            if true_obj < best_int_obj:
                print(f"    (New best solution, updating incumbent from {best_int_obj:.2f} to {true_obj:.2f})")
                best_int_obj = true_obj
                best_int_solution = solution_cols
                # Prune any nodes in the heap that are now worse than our new best solution
                heap = [(p_lb, p_id, p_p, p_ft, p_fs, p_req) for p_lb, p_id, p_p, p_ft, p_fs, p_req in heap if p_lb < best_int_obj]
                heapq.heapify(heap)
            continue

        # --- Branching Logic (unchanged) ---
        zvals = compute_pairslot_z_from_solution(included_cols, x_vals)
        frac_items = sorted([(abs(val - 0.5), (p, val)) for p, val in zvals.items() if 1e-6 < val < 1 - 1e-6])
        if frac_items:
            _, ((i,j,s), val) = frac_items[0]
            print(f" -> Branch on pair-slot z({i},{j},{s}) = {val:.4f}")
            child1_req = tuple(list(require_list) + [(i,j,s)])
            heapq.heappush(heap, (obj, node_id_gen, included_cols, forbid_triplets, forbid_signatures, child1_req)); node_id_gen += 1
            child2_trip = set(forbid_triplets); child2_trip.add((i,j,s)); child2_trip.add((j,i,s))
            heapq.heappush(heap, (obj, node_id_gen, included_cols, frozenset(child2_trip), forbid_signatures, require_list)); node_id_gen += 1
        else:
            frac_cols = [(k, v) for k, v in enumerate(x_vals) if 1e-6 < v < 1-1e-6]
            if not frac_cols:
                print(" -> Z and X are integral, but check failed. Pruning.")
                continue
            by_team = {}
            for k, val in frac_cols: by_team.setdefault(included_cols[k]['team'], []).append((val, k))
            target_team = max(by_team, key=lambda t: sum(v for v,k in by_team[t]))
            _, k_forbid = max(by_team[target_team])
            col_forbid = included_cols[k_forbid]
            sig_forbid = (col_forbid['team'], tuple(col_forbid['tour']['opp_seq']), tuple(col_forbid['tour']['home_flags']))
            print(f" -> Fallback branch on team {team_names[target_team]} (x_{k_forbid}={x_vals[k_forbid]:.4f})")
            child1_sigs = set(forbid_signatures); child1_sigs.add(sig_forbid)
            heapq.heappush(heap, (obj, node_id_gen, included_cols, forbid_triplets, frozenset(child1_sigs), require_list)); node_id_gen += 1
            other_frac = [c for c in by_team[target_team] if c[1] != k_forbid]
            if other_frac:
                _, k2_forbid = max(other_frac)
                col2_forbid = included_cols[k2_forbid]
                sig2_forbid = (col2_forbid['team'], tuple(col2_forbid['tour']['opp_seq']), tuple(col2_forbid['tour']['home_flags']))
                child2_sigs = set(forbid_signatures); child2_sigs.add(sig2_forbid)
                heapq.heappush(heap, (obj, node_id_gen, included_cols, forbid_triplets, frozenset(child2_sigs), require_list)); node_id_gen += 1

    print(f"\nBranch-and-price finished. Nodes processed: {nodes_processed}")
    if best_int_solution is None:
        print("No integer solution found within limits.")
    else:
        print(f"Best integer obj = {best_int_obj:.2f}")
    return best_int_obj, best_int_solution
    
# ----------------------- Main Execution (Corrected) -----------------------
if __name__ == "__main__":
    print("Generating a valid initial pool...")
    initial_pool = []
    dummy_duals = {
        'team': np.zeros(n),
        'pair_slot': np.zeros(P * m_slots),
        'home_cons': np.zeros(P * m_slots),
        'require': np.array([])
    }
    for t in range(n):
        # <<< BUG FIX: Call the solver in "initial_generation" mode >>>
        initial_tour = solve_pricing_subproblem(t, dummy_duals, initial_generation=True)
        if initial_tour:
            initial_pool.append({'team': t, 'tour': initial_tour})
        else:
            raise RuntimeError(f"Could not generate a valid initial tour for team {team_names[t]}. The problem may be infeasible.")

    print(f"Initial pool size: {len(initial_pool)}")
    
    start_total = time.time()
    best_obj, best_solution = branch_and_price_gurobi(initial_pool, time_limit_nodes=36000.0, max_nodes=5000)
    print(f"\nTotal elapsed time: {time.time() - start_total:.2f} seconds")

    if best_solution is not None:
        sel = []
        for col in sorted(best_solution, key=lambda c: c['team']):
            t, tour = col['team'], col['tour']
            sel.append({
                'team': team_names[t], 'cost': tour['cost'],
                'opp_seq': tuple(team_names[o] for o in tour['opp_seq']),
                'home_flags': tuple(['H' if h else 'A' for h in tour['home_flags']])
            })
        df = pd.DataFrame(sel)
        print("\nBest integer solution found:\n")
        print(df.to_string(index=False))
    else:
        print("\nNo integer solution was found.")
# Out:
# Setup: n=6, slots=10, pairs=15
# Solving for NL6 instance.
# Generating a valid initial pool...
# Initial pool size: 6
#
# Node 0 (processed 1) lb=0.00 |B_T|=0 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15018825.02, columns = 941
#  -> Branch on pair-slot z(2,4,7) = 0.4732
#
# Node 1 (processed 2) lb=15018825.02 |B_T|=0 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019027.77, columns = 1338
#  -> Branch on pair-slot z(1,2,0) = 0.5018
#
# Node 2 (processed 3) lb=15018825.02 |B_T|=2 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15018865.79, columns = 982
#  -> Branch on pair-slot z(2,5,3) = 0.4634
#
# Node 5 (processed 4) lb=15018865.79 |B_T|=2 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019326.93, columns = 1271
#  -> Branch on pair-slot z(0,5,9) = 0.5084
#
# Node 6 (processed 5) lb=15018865.79 |B_T|=4 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15018991.98, columns = 996
#  -> Branch on pair-slot z(2,5,5) = 0.3887
#
# Node 9 (processed 6) lb=15018991.98 |B_T|=4 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019477.33, columns = 1216
#  -> Branch on pair-slot z(0,1,4) = 0.4878
#
# Node 10 (processed 7) lb=15018991.98 |B_T|=6 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15019042.56, columns = 1008
#  -> Branch on pair-slot z(2,5,4) = 0.4502
#
# Node 3 (processed 8) lb=15019027.77 |B_T|=0 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15019297.14, columns = 1680
#  -> Branch on pair-slot z(0,4,3) = 0.5034
#
# Node 4 (processed 9) lb=15019027.77 |B_T|=2 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019280.72, columns = 1468
#  -> Branch on pair-slot z(1,2,1) = 0.5059
#
# Node 13 (processed 10) lb=15019042.56 |B_T|=6 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019521.35, columns = 1185
#  -> Branch on pair-slot z(0,3,4) = 0.5172
#
# Node 14 (processed 11) lb=15019042.56 |B_T|=8 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15019130.99, columns = 1056
#  -> Branch on pair-slot z(1,5,1) = 0.4352
#
# Node 21 (processed 12) lb=15019130.99 |B_T|=8 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019688.58, columns = 1375
#  -> Branch on pair-slot z(2,5,8) = 0.4933
#
# Node 22 (processed 13) lb=15019130.99 |B_T|=10 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15019218.00, columns = 1062
#  -> Branch on pair-slot z(0,5,4) = 0.4870
#
# Node 25 (processed 14) lb=15019218.00 |B_T|=10 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019772.18, columns = 1329
#  -> Branch on pair-slot z(0,1,6) = 0.4929
#
# Node 26 (processed 15) lb=15019218.00 |B_T|=12 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15019576.47, columns = 1142
#  -> Branch on pair-slot z(1,2,3) = 0.4767
#
# Node 17 (processed 16) lb=15019280.72 |B_T|=2 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15019858.21, columns = 1884
#  -> Branch on pair-slot z(2,3,8) = 0.5105
#
# Node 18 (processed 17) lb=15019280.72 |B_T|=4 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15020046.43, columns = 1690
#  -> Branch on pair-slot z(0,1,4) = 0.4935
#
# Node 15 (processed 18) lb=15019297.14 |B_T|=0 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15170017.71, columns = 2817
#  -> Branch on pair-slot z(3,4,4) = 0.5051
#
# Node 16 (processed 19) lb=15019297.14 |B_T|=2 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15019958.05, columns = 1782
#  -> Branch on pair-slot z(1,5,8) = 0.5093
#
# Node 7 (processed 20) lb=15019326.93 |B_T|=2 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15020231.10, columns = 1868
#  -> Branch on pair-slot z(0,4,0) = 0.4978
#
# Node 8 (processed 21) lb=15019326.93 |B_T|=4 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019443.86, columns = 1319
#  -> Branch on pair-slot z(1,2,6) = 0.4722
#
# Node 41 (processed 22) lb=15019443.86 |B_T|=4 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15146989.87, columns = 1670
#  -> Branch on pair-slot z(0,5,6) = 0.5017
#
# Node 42 (processed 23) lb=15019443.86 |B_T|=6 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15020786.09, columns = 1356
#  -> Branch on pair-slot z(2,4,1) = 0.5025
#
# Node 11 (processed 24) lb=15019477.33 |B_T|=4 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15972881.26, columns = 1474
#  -> Branch on pair-slot z(1,3,5) = 0.5023
#
# Node 12 (processed 25) lb=15019477.33 |B_T|=6 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15019842.22, columns = 1192
#  -> Branch on pair-slot z(0,2,7) = 0.5091
#
# Node 19 (processed 26) lb=15019521.35 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15222658.37, columns = 1498
#  -> Branch on pair-slot z(1,3,6) = 0.5191
#
# Node 20 (processed 27) lb=15019521.35 |B_T|=8 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15020573.38, columns = 1129
#  -> Branch on pair-slot z(2,4,6) = 0.4707
#
# Node 29 (processed 28) lb=15019576.47 |B_T|=12 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15020126.30, columns = 1384
#  -> Branch on pair-slot z(0,2,7) = 0.4862
#
# Node 30 (processed 29) lb=15019576.47 |B_T|=14 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15019857.20, columns = 1126
#  -> Branch on pair-slot z(2,5,9) = 0.5019
#
# Node 23 (processed 30) lb=15019688.58 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15020963.59, columns = 1646
#  -> Branch on pair-slot z(1,3,6) = 0.5015
#
# Node 24 (processed 31) lb=15019688.58 |B_T|=10 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15116570.59, columns = 1684
#  -> Branch on pair-slot z(1,4,3) = 0.4997
#
# Node 27 (processed 32) lb=15019772.18 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15744987.92, columns = 1734
#  -> Branch on pair-slot z(2,4,6) = 0.4995
#
# Node 28 (processed 33) lb=15019772.18 |B_T|=12 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15152984.29, columns = 1392
#  -> Branch on pair-slot z(3,5,5) = 0.4794
#
# Node 49 (processed 34) lb=15019842.22 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16237740.49, columns = 1304
#  -> Branch on pair-slot z(2,4,6) = 0.5046
#
# Node 50 (processed 35) lb=15019842.22 |B_T|=8 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15346155.31, columns = 1330
#  -> Branch on pair-slot z(0,3,4) = 0.4888
#
# Node 57 (processed 36) lb=15019857.20 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15420450.22, columns = 1396
#  -> Branch on pair-slot z(0,5,3) = 0.4979
#
# Node 58 (processed 37) lb=15019857.20 |B_T|=16 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15020686.94, columns = 1238
#  -> Branch on pair-slot z(0,5,5) = 0.4929
#
# Node 31 (processed 38) lb=15019858.21 |B_T|=2 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15020938.73, columns = 2496
#  -> Branch on pair-slot z(2,3,0) = 0.4906
#
# Node 32 (processed 39) lb=15019858.21 |B_T|=4 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15020267.29, columns = 2078
#  -> Branch on pair-slot z(0,1,5) = 0.4919
#
# Node 37 (processed 40) lb=15019958.05 |B_T|=2 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15020774.65, columns = 2538
#  -> Branch on pair-slot z(0,2,6) = 0.5122
#
# Node 38 (processed 41) lb=15019958.05 |B_T|=4 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15020777.85, columns = 1777
#  -> Branch on pair-slot z(0,2,3) = 0.4859
#
# Node 33 (processed 42) lb=15020046.43 |B_T|=4 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15020970.65, columns = 2277
#  -> Branch on pair-slot z(0,4,0) = 0.4838
#
# Node 34 (processed 43) lb=15020046.43 |B_T|=6 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15020218.99, columns = 1668
#  -> Branch on pair-slot z(1,2,2) = 0.4951
#
# Node 55 (processed 44) lb=15020126.30 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15609319.71, columns = 1643
#  -> Branch on pair-slot z(4,5,4) = 0.4940
#
# Node 56 (processed 45) lb=15020126.30 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15021290.85, columns = 1395
#  -> Branch on pair-slot z(4,5,4) = 0.4994
#
# Node 85 (processed 46) lb=15020218.99 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15021567.47, columns = 2242
#  -> Branch on pair-slot z(1,2,6) = 0.5013
#
# Node 86 (processed 47) lb=15020218.99 |B_T|=8 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15021147.46, columns = 2139
#  -> Branch on pair-slot z(1,5,3) = 0.4974
#
# Node 39 (processed 48) lb=15020231.10 |B_T|=2 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15637002.23, columns = 2469
#  -> Branch on pair-slot z(1,4,9) = 0.4926
#
# Node 40 (processed 49) lb=15020231.10 |B_T|=4 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15146363.85, columns = 2495
#  -> Branch on pair-slot z(0,4,1) = 0.4995
#
# Node 77 (processed 50) lb=15020267.29 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15445059.31, columns = 2415
#  -> Branch on pair-slot z(0,3,4) = 0.4977
#
# Node 78 (processed 51) lb=15020267.29 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15406751.06, columns = 2290
#  -> Branch on pair-slot z(0,2,6) = 0.5070
#
# Node 53 (processed 52) lb=15020573.38 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16212880.77, columns = 1209
#  -> Branch on pair-slot z(0,5,6) = 0.4818
#
# Node 54 (processed 53) lb=15020573.38 |B_T|=10 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15524528.91, columns = 1098
#  -> Branch on pair-slot z(3,5,6) = 0.4993
#
# Node 73 (processed 54) lb=15020686.94 |B_T|=16 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16117351.33, columns = 1440
#  -> Branch on pair-slot z(0,1,7) = 0.4980
#
# Node 74 (processed 55) lb=15020686.94 |B_T|=18 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15282540.17, columns = 1445
#  -> Branch on pair-slot z(0,3,8) = 0.5061
#
# Node 79 (processed 56) lb=15020774.65 |B_T|=2 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15625023.17, columns = 2941
#  -> Branch on pair-slot z(1,2,3) = 0.4945
#
# Node 80 (processed 57) lb=15020774.65 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15763927.48, columns = 2699
#  -> Branch on pair-slot z(0,1,7) = 0.5050
#
# Node 81 (processed 58) lb=15020777.85 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15540959.15, columns = 1930
#  -> Branch on pair-slot z(1,5,1) = 0.4824
#
# Node 82 (processed 59) lb=15020777.85 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15038837.03, columns = 1865
#  -> Branch on pair-slot z(3,4,5) = 0.5263
#
# Node 45 (processed 60) lb=15020786.09 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15531369.20, columns = 1730
#  -> Branch on pair-slot z(3,4,3) = 0.4978
#
# Node 46 (processed 61) lb=15020786.09 |B_T|=8 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15022315.51, columns = 1592
#  -> Branch on pair-slot z(0,3,8) = 0.5010
#
# Node 75 (processed 62) lb=15020938.73 |B_T|=2 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15022207.19, columns = 3807
#  -> Branch on pair-slot z(0,4,0) = 0.4934
#
# Node 76 (processed 63) lb=15020938.73 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15021990.30, columns = 2719
#  -> Branch on pair-slot z(2,4,2) = 0.4670
#
# Node 59 (processed 64) lb=15020963.59 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15958429.58, columns = 1780
#  -> Branch on pair-slot z(0,5,9) = 0.5189
#
# Node 60 (processed 65) lb=15020963.59 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15956958.56, columns = 1502
#  -> Branch on pair-slot z(2,4,5) = 0.4815
#
# Node 83 (processed 66) lb=15020970.65 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15022033.54, columns = 3262
#  -> Branch on pair-slot z(1,5,5) = 0.5049
#
# Node 84 (processed 67) lb=15020970.65 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15023302.25, columns = 2455
#  -> Branch on pair-slot z(0,5,2) = 0.4908
#
# Node 93 (processed 68) lb=15021147.46 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15022475.40, columns = 3005
#  -> Branch on pair-slot z(3,4,8) = 0.4981
#
# Node 94 (processed 69) lb=15021147.46 |B_T|=10 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15022494.26, columns = 2293
#  -> Branch on pair-slot z(0,1,5) = 0.4806
#
# Node 89 (processed 70) lb=15021290.85 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16172303.35, columns = 1533
#  -> Branch on pair-slot z(1,4,6) = 0.5059
#
# Node 90 (processed 71) lb=15021290.85 |B_T|=16 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16167336.95, columns = 1458
#  -> Branch on pair-slot z(2,5,9) = 0.5010
#
# Node 91 (processed 72) lb=15021567.47 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15691576.42, columns = 3608
#  -> Branch on pair-slot z(0,4,1) = 0.5000
#
# Node 92 (processed 73) lb=15021567.47 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15689407.66, columns = 2965
#  -> Branch on pair-slot z(4,5,2) = 0.4795
#
# Node 125 (processed 74) lb=15021990.30 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15192338.67, columns = 3645
#  -> Branch on pair-slot z(0,1,2) = 0.4792
#
# Node 126 (processed 75) lb=15021990.30 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15023341.76, columns = 2855
#  -> Branch on pair-slot z(0,3,0) = 0.5000
#
# Node 131 (processed 76) lb=15022033.54 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15776394.78, columns = 3807
#  -> Branch on pair-slot z(3,4,5) = 0.5004
#
# Node 132 (processed 77) lb=15022033.54 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15022475.19, columns = 3224
#  -> Branch on pair-slot z(0,5,7) = 0.5000
#
# Node 123 (processed 78) lb=15022207.19 |B_T|=2 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 15023523.67, columns = 5321
#  -> Branch on pair-slot z(3,5,4) = 0.5088
#
# Node 124 (processed 79) lb=15022207.19 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15226423.85, columns = 4043
#  -> Branch on pair-slot z(1,3,4) = 0.5152
#
# Node 121 (processed 80) lb=15022315.51 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15321891.67, columns = 1759
#  -> Branch on pair-slot z(0,4,3) = 0.4966
#
# Node 122 (processed 81) lb=15022315.51 |B_T|=10 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15103019.54, columns = 1429
#  -> Branch on pair-slot z(1,5,9) = 0.4969
#
# Node 153 (processed 82) lb=15022475.19 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16024162.56, columns = 3810
#  -> Branch on pair-slot z(2,3,0) = 0.5000
#
# Node 154 (processed 83) lb=15022475.19 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15552069.43, columns = 3480
#  -> Branch on pair-slot z(1,2,3) = 0.5031
#
# Node 135 (processed 84) lb=15022475.40 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15023431.84, columns = 3730
#  -> Branch on pair-slot z(0,4,9) = 0.4973
#
# Node 136 (processed 85) lb=15022475.40 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15190021.71, columns = 3038
#  -> Branch on pair-slot z(0,5,1) = 0.5158
#
# Node 137 (processed 86) lb=15022494.26 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15673369.95, columns = 2637
#  -> Branch on pair-slot z(2,4,2) = 0.5061
#
# Node 138 (processed 87) lb=15022494.26 |B_T|=12 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15340045.39, columns = 2515
#  -> Branch on pair-slot z(0,5,5) = 0.4990
#
# Node 133 (processed 88) lb=15023302.25 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15574567.73, columns = 2960
#  -> Branch on pair-slot z(0,4,9) = 0.5092
#
# Node 134 (processed 89) lb=15023302.25 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15410259.59, columns = 2367
#  -> Branch on pair-slot z(4,5,6) = 0.4798
#
# Node 149 (processed 90) lb=15023341.76 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16095474.57, columns = 3011
#  -> Branch on pair-slot z(1,5,0) = 0.5009
#
# Node 150 (processed 91) lb=15023341.76 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15328645.56, columns = 2825
#  -> Branch on pair-slot z(0,4,3) = 0.5005
#
# Node 167 (processed 92) lb=15023431.84 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15342750.04, columns = 4011
#  -> Branch on pair-slot z(1,3,0) = 0.4794
#
# Node 168 (processed 93) lb=15023431.84 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15660873.38, columns = 3408
#  -> Branch on pair-slot z(0,3,9) = 0.5070
#
# Node 155 (processed 94) lb=15023523.67 |B_T|=2 |B_S|=0 |R|=6
#  -> Node LP obj (lower bound) = 16357735.83, columns = 5615
#  -> Branch on pair-slot z(0,4,8) = 0.4982
#
# Node 156 (processed 95) lb=15023523.67 |B_T|=4 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 15913395.43, columns = 4624
#  -> Branch on pair-slot z(0,4,8) = 0.4948
#
# Node 117 (processed 96) lb=15038837.03 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15865338.96, columns = 1900
#  -> Branch on pair-slot z(2,3,4) = 0.4430
#
# Node 118 (processed 97) lb=15038837.03 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15595778.96, columns = 1658
#  -> Branch on pair-slot z(0,3,3) = 0.5218
#
# Node 161 (processed 98) lb=15103019.54 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15126870.18, columns = 1653
#  -> Branch on pair-slot z(0,3,1) = 0.4859
#
# Node 162 (processed 99) lb=15103019.54 |B_T|=12 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15489393.30, columns = 1356
#  -> Branch on pair-slot z(4,5,9) = 0.4922
#
# Node 61 (processed 100) lb=15116570.59 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15337700.72, columns = 2104
#  -> Branch on pair-slot z(2,3,8) = 0.4685
#
# Node 62 (processed 101) lb=15116570.59 |B_T|=12 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15515594.32, columns = 1858
#  -> Branch on pair-slot z(2,5,6) = 0.4923
#
# Node 195 (processed 102) lb=15126870.18 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15946290.11, columns = 1663
#  -> Branch on pair-slot z(4,5,1) = 0.4927
#
# Node 196 (processed 103) lb=15126870.18 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15024174.30, columns = 1559
#  -> Branch on pair-slot z(2,4,6) = 0.5026
#
# Node 205 (processed 104) lb=15024174.30 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16894701.01, columns = 1773
#  -> Branch on pair-slot z(0,4,9) = 0.5320
#
# Node 206 (processed 105) lb=15024174.30 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16462486.26, columns = 1530
#  -> Branch on pair-slot z(2,4,2) = 0.4913
#
# Node 97 (processed 106) lb=15146363.85 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16212946.59, columns = 2846
#  -> Branch on pair-slot z(1,2,6) = 0.4912
#
# Node 98 (processed 107) lb=15146363.85 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17224627.19, columns = 2955
#  -> Branch on pair-slot z(0,4,8) = 0.5017
#
# Node 43 (processed 108) lb=15146989.87 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15820077.43, columns = 1853
#  -> Branch on pair-slot z(2,4,5) = 0.5004
#
# Node 44 (processed 109) lb=15146989.87 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16027099.40, columns = 1603
#  -> Branch on pair-slot z(3,4,0) = 0.4871
#
# Node 65 (processed 110) lb=15152984.29 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16037508.04, columns = 1482
#  -> Branch on pair-slot z(2,5,9) = 0.4813
#
# Node 66 (processed 111) lb=15152984.29 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16284410.52, columns = 1402
#  -> Branch on pair-slot z(2,4,8) = 0.5107
#
# Node 35 (processed 112) lb=15170017.71 |B_T|=0 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16566979.71, columns = 3075
#  -> Branch on pair-slot z(0,2,8) = 0.4919
#
# Node 36 (processed 113) lb=15170017.71 |B_T|=2 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15636735.54, columns = 2668
#  -> Branch on pair-slot z(0,1,4) = 0.4936
#
# Node 169 (processed 114) lb=15190021.71 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16322092.01, columns = 3123
#  -> Branch on pair-slot z(0,5,7) = 0.5045
#
# Node 170 (processed 115) lb=15190021.71 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15443312.87, columns = 2555
#  -> Branch on pair-slot z(3,5,6) = 0.4996
#
# Node 147 (processed 116) lb=15192338.67 |B_T|=4 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 15925448.18, columns = 4268
#  -> Branch on pair-slot z(0,5,8) = 0.5000
#
# Node 148 (processed 117) lb=15192338.67 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16245567.65, columns = 3794
#  -> Branch on pair-slot z(1,4,5) = 0.5174
#
# Node 51 (processed 118) lb=15222658.37 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15791283.74, columns = 1607
#  -> Branch on pair-slot z(0,5,6) = 0.4952
#
# Node 52 (processed 119) lb=15222658.37 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15780658.71, columns = 1309
#  -> Branch on pair-slot z(2,3,3) = 0.5351
#
# Node 157 (processed 120) lb=15226423.85 |B_T|=4 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 17023893.09, columns = 4626
#  -> Branch on pair-slot z(1,4,8) = 0.5033
#
# Node 158 (processed 121) lb=15226423.85 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15100043.70, columns = 4071
#  -> Branch on pair-slot z(0,1,2) = 0.5000
#
# Node 241 (processed 122) lb=15100043.70 |B_T|=6 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 16168844.41, columns = 4185
#  -> Branch on pair-slot z(0,4,9) = 0.4975
#
# Node 242 (processed 123) lb=15100043.70 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 15937241.81, columns = 4037
#  -> Branch on pair-slot z(1,3,5) = 0.5006
#
# Node 109 (processed 124) lb=15282540.17 |B_T|=18 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16189165.38, columns = 1573
#  -> Branch on pair-slot z(0,1,0) = 0.4998
#
# Node 110 (processed 125) lb=15282540.17 |B_T|=20 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 15626752.74, columns = 1263
#  -> Branch on pair-slot z(4,5,4) = 0.5072
#
# Node 159 (processed 126) lb=15321891.67 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16160522.27, columns = 1877
#  -> Branch on pair-slot z(0,2,4) = 0.4680
#
# Node 160 (processed 127) lb=15321891.67 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16382621.22, columns = 1781
#  -> Branch on pair-slot z(2,3,1) = 0.4883
#
# Node 181 (processed 128) lb=15328645.56 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17022846.87, columns = 3018
#  -> Branch on pair-slot z(3,4,5) = 0.5204
#
# Node 182 (processed 129) lb=15328645.56 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15862961.64, columns = 2700
#  -> Branch on pair-slot z(3,5,1) = 0.5064
#
# Node 199 (processed 130) lb=15337700.72 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16264568.97, columns = 2185
#  -> Branch on pair-slot z(0,3,1) = 0.5002
#
# Node 200 (processed 131) lb=15337700.72 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15698496.55, columns = 1815
#  -> Branch on pair-slot z(0,1,5) = 0.4905
#
# Node 173 (processed 132) lb=15340045.39 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15674755.75, columns = 2775
#  -> Branch on pair-slot z(1,2,6) = 0.5008
#
# Node 174 (processed 133) lb=15340045.39 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15023161.97, columns = 2625
#  -> Branch on pair-slot z(0,3,7) = 0.4988
#
# Node 265 (processed 134) lb=15023161.97 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15586885.63, columns = 2797
#  -> Branch on pair-slot z(0,1,9) = 0.4904
#
# Node 266 (processed 135) lb=15023161.97 |B_T|=16 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15794311.32, columns = 2425
#  -> Branch on pair-slot z(1,5,2) = 0.5042
#
# Node 183 (processed 136) lb=15342750.04 |B_T|=8 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 16854865.71, columns = 4319
#  -> Branch on pair-slot z(3,5,9) = 0.5179
#
# Node 184 (processed 137) lb=15342750.04 |B_T|=10 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17526242.64, columns = 3950
#  -> Branch on pair-slot z(3,5,7) = 0.5020
#
# Node 69 (processed 138) lb=15346155.31 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16239593.73, columns = 1409
#  -> Branch on pair-slot z(4,5,4) = 0.5036
#
# Node 70 (processed 139) lb=15346155.31 |B_T|=10 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15513378.90, columns = 1126
#  -> Branch on pair-slot z(2,4,9) = 0.5139
#
# Node 101 (processed 140) lb=15406751.06 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16190596.15, columns = 2520
#  -> Branch on pair-slot z(0,5,7) = 0.4871
#
# Node 102 (processed 141) lb=15406751.06 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15876286.40, columns = 2744
#  -> Branch on pair-slot z(0,5,5) = 0.5023
#
# Node 177 (processed 142) lb=15410259.59 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16437861.88, columns = 2489
#  -> Branch on pair-slot z(0,3,6) = 0.4968
#
# Node 178 (processed 143) lb=15410259.59 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15784153.66, columns = 2244
#  -> Branch on pair-slot z(0,5,6) = 0.5107
#
# Node 71 (processed 144) lb=15420450.22 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16582700.13, columns = 1502
#  -> Branch on pair-slot z(0,3,9) = 0.5029
#
# Node 72 (processed 145) lb=15420450.22 |B_T|=16 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15810561.03, columns = 1455
#  -> Branch on pair-slot z(1,3,5) = 0.4935
#
# Node 229 (processed 146) lb=15443312.87 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16513669.46, columns = 2559
#  -> Branch on pair-slot z(2,3,0) = 0.4936
#
# Node 230 (processed 147) lb=15443312.87 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15929329.91, columns = 2254
#  -> Branch on pair-slot z(1,5,1) = 0.5187
#
# Node 99 (processed 148) lb=15445059.31 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16923734.76, columns = 2731
#  -> Branch on pair-slot z(3,4,8) = 0.5002
#
# Node 100 (processed 149) lb=15445059.31 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16521066.16, columns = 2407
#  -> Branch on pair-slot z(2,5,5) = 0.4985
#
# Node 197 (processed 150) lb=15489393.30 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16838683.61, columns = 1448
#  -> Branch on pair-slot z(0,2,4) = 0.5224
#
# Node 198 (processed 151) lb=15489393.30 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15947257.99, columns = 1360
#  -> Branch on pair-slot z(0,5,8) = 0.5074
#
# Node 277 (processed 152) lb=15513378.90 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16156645.81, columns = 1160
#  -> Branch on pair-slot z(2,3,6) = 0.4933
#
# Node 278 (processed 153) lb=15513378.90 |B_T|=12 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16088281.15, columns = 1037
#  -> Branch on pair-slot z(2,5,2) = 0.5089
#
# Node 201 (processed 154) lb=15515594.32 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16715662.82, columns = 2049
#  -> Branch on pair-slot z(2,3,7) = 0.4811
#
# Node 202 (processed 155) lb=15515594.32 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15882673.14, columns = 1924
#  -> Branch on pair-slot z(3,5,5) = 0.5049
#
# Node 105 (processed 156) lb=15524528.91 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16541320.47, columns = 1265
#  -> Branch on pair-slot z(0,3,2) = 0.4804
#
# Node 106 (processed 157) lb=15524528.91 |B_T|=12 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15276130.66, columns = 1209
#  -> Branch on pair-slot z(2,4,5) = 0.5238
#
# Node 313 (processed 158) lb=15276130.66 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16978330.71, columns = 1315
#  -> Branch on pair-slot z(1,3,4) = 0.5218
#
# Node 314 (processed 159) lb=15276130.66 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 17593141.26, columns = 1273
#  -> Branch on pair-slot z(1,4,8) = 0.4962
#
# Node 119 (processed 160) lb=15531369.20 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16567203.18, columns = 1843
#  -> Branch on pair-slot z(1,4,5) = 0.5134
#
# Node 120 (processed 161) lb=15531369.20 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16118284.80, columns = 1779
#  -> Branch on pair-slot z(3,5,1) = 0.5197
#
# Node 115 (processed 162) lb=15540959.15 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16337462.47, columns = 2035
#  -> Branch on pair-slot z(1,3,7) = 0.4931
#
# Node 116 (processed 163) lb=15540959.15 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15805754.92, columns = 1982
#  -> Branch on pair-slot z(1,4,6) = 0.5190
#
# Node 165 (processed 164) lb=15552069.43 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16570339.09, columns = 3608
#  -> Branch on pair-slot z(2,3,2) = 0.4721
#
# Node 166 (processed 165) lb=15552069.43 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16031196.09, columns = 3697
#  -> Branch on pair-slot z(1,2,2) = 0.4967
#
# Node 175 (processed 166) lb=15574567.73 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17054301.29, columns = 3283
#  -> Branch on pair-slot z(2,3,1) = 0.4868
#
# Node 176 (processed 167) lb=15574567.73 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17022085.18, columns = 2970
#  -> Branch on pair-slot z(0,2,9) = 0.4846
#
# Node 267 (processed 168) lb=15586885.63 |B_T|=14 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16961264.59, columns = 2882
#  -> Branch on pair-slot z(3,4,8) = 0.5082
#
# Node 268 (processed 169) lb=15586885.63 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 18103304.32, columns = 2845
#  -> Branch on pair-slot z(1,3,9) = 0.4775
#
# Node 193 (processed 170) lb=15595778.96 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16517544.35, columns = 1678
#  -> Branch on pair-slot z(1,3,8) = 0.4896
#
# Node 194 (processed 171) lb=15595778.96 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16473084.87, columns = 1438
#  -> Branch on pair-slot z(0,2,8) = 0.4869
#
# Node 87 (processed 172) lb=15609319.71 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17339991.64, columns = 1717
#  -> Branch on pair-slot z(2,5,9) = 0.5007
#
# Node 88 (processed 173) lb=15609319.71 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 18571027.08, columns = 1696
#  -> Branch on pair-slot z(3,4,7) = 0.5034
#
# Node 111 (processed 174) lb=15625023.17 |B_T|=2 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 17483910.30, columns = 3232
#  -> Branch on pair-slot z(3,5,7) = 0.4888
#
# Node 112 (processed 175) lb=15625023.17 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17260426.91, columns = 3019
#  -> Branch on pair-slot z(0,2,8) = 0.5006
#
# Node 249 (processed 176) lb=15626752.74 |B_T|=20 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 17177512.99, columns = 1263
#  -> Branch on pair-slot z(3,5,5) = 0.4978
#
# Node 250 (processed 177) lb=15626752.74 |B_T|=22 |B_S|=0 |R|=0
#  -> Node LP obj (lower bound) = 18228257.51, columns = 1239
#  -> Branch on pair-slot z(0,5,2) = 0.5008
#
# Node 225 (processed 178) lb=15636735.54 |B_T|=2 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16551622.63, columns = 2962
#  -> Branch on pair-slot z(1,5,5) = 0.5072
#
# Node 226 (processed 179) lb=15636735.54 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16683698.59, columns = 2661
#  -> Branch on pair-slot z(2,3,3) = 0.4421
#
# Node 95 (processed 180) lb=15637002.23 |B_T|=2 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16612155.43, columns = 2665
#  -> Branch on pair-slot z(0,1,8) = 0.5093
#
# Node 96 (processed 181) lb=15637002.23 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16484681.30, columns = 2760
#  -> Branch on pair-slot z(1,4,3) = 0.5000
#
# Node 185 (processed 182) lb=15660873.38 |B_T|=10 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16781409.31, columns = 3472
#  -> Branch on pair-slot z(3,5,6) = 0.5078
#
# Node 186 (processed 183) lb=15660873.38 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16765801.47, columns = 3248
#  -> Branch on pair-slot z(0,2,4) = 0.5448
#
# Node 171 (processed 184) lb=15673369.95 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17588491.25, columns = 2938
#  -> Branch on pair-slot z(3,4,9) = 0.4896
#
# Node 172 (processed 185) lb=15673369.95 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17281735.34, columns = 2449
#  -> Branch on pair-slot z(1,4,2) = 0.5048
#
# Node 263 (processed 186) lb=15674755.75 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 18149400.58, columns = 3118
#  -> Branch on pair-slot z(0,2,8) = 0.5124
#
# Node 264 (processed 187) lb=15674755.75 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15907714.28, columns = 3047
#  -> Branch on pair-slot z(3,4,1) = 0.4846
#
# Node 145 (processed 188) lb=15689407.66 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16775446.93, columns = 3257
#  -> Branch on pair-slot z(0,1,9) = 0.4984
#
# Node 146 (processed 189) lb=15689407.66 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 15689891.53, columns = 2651
#  -> Branch on pair-slot z(0,4,4) = 0.4965
#
# Node 377 (processed 190) lb=15689891.53 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16334586.93, columns = 2758
#  -> Branch on pair-slot z(0,5,2) = 0.5132
#
# Node 378 (processed 191) lb=15689891.53 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16335977.19, columns = 2453
#  -> Branch on pair-slot z(1,5,0) = 0.4891
#
# Node 143 (processed 192) lb=15691576.42 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17115095.02, columns = 3826
#  -> Branch on pair-slot z(3,4,2) = 0.5450
#
# Node 144 (processed 193) lb=15691576.42 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 15969839.51, columns = 3389
#  -> Branch on pair-slot z(3,4,5) = 0.5000
#
# Node 261 (processed 194) lb=15698496.55 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17067046.75, columns = 1841
#  -> Branch on pair-slot z(2,5,0) = 0.5033
#
# Node 262 (processed 195) lb=15698496.55 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16290963.55, columns = 1614
#  -> Branch on pair-slot z(1,5,5) = 0.5039
#
# Node 63 (processed 196) lb=15744987.92 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16701034.49, columns = 1934
#  -> Branch on pair-slot z(2,5,2) = 0.4862
#
# Node 64 (processed 197) lb=15744987.92 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16629275.37, columns = 1830
#  -> Branch on pair-slot z(2,4,9) = 0.4897
#
# Node 113 (processed 198) lb=15763927.48 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16945422.76, columns = 2852
#  -> Branch on pair-slot z(3,5,0) = 0.4996
#
# Node 114 (processed 199) lb=15763927.48 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16360204.87, columns = 2817
#  -> Branch on pair-slot z(1,4,6) = 0.4718
#
# Node 151 (processed 200) lb=15776394.78 |B_T|=4 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 17130414.23, columns = 3944
#  -> Branch on pair-slot z(0,3,9) = 0.5027
#
# Node 152 (processed 201) lb=15776394.78 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17143152.00, columns = 3519
#  -> Branch on pair-slot z(1,4,1) = 0.4972
#
# Node 237 (processed 202) lb=15780658.71 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17346178.52, columns = 1317
#  -> Branch on pair-slot z(2,4,5) = 0.4966
#
# Node 238 (processed 203) lb=15780658.71 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16465265.31, columns = 1245
#  -> Branch on pair-slot z(1,4,6) = 0.4326
#
# Node 285 (processed 204) lb=15784153.66 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17108621.41, columns = 2428
#  -> Branch on pair-slot z(0,5,1) = 0.4936
#
# Node 286 (processed 205) lb=15784153.66 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16711331.85, columns = 2091
#  -> Branch on pair-slot z(1,3,3) = 0.5031
#
# Node 235 (processed 206) lb=15791283.74 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 19181424.58, columns = 1652
#  -> Branch on pair-slot z(2,3,3) = 0.5092
#
# Node 236 (processed 207) lb=15791283.74 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16726669.85, columns = 1586
#  -> Branch on pair-slot z(3,5,2) = 0.4907
#
# Node 269 (processed 208) lb=15794311.32 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17351637.77, columns = 2553
#  -> Branch on pair-slot z(2,4,2) = 0.4825
#
# Node 270 (processed 209) lb=15794311.32 |B_T|=18 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16476537.33, columns = 2434
#  -> Branch on pair-slot z(3,4,6) = 0.4799
#
# Node 325 (processed 210) lb=15805754.92 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17506413.73, columns = 2095
#  -> Branch on pair-slot z(1,3,8) = 0.4918
#
# Node 326 (processed 211) lb=15805754.92 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17246607.96, columns = 2002
#  -> Branch on pair-slot z(2,5,5) = 0.5259
#
# Node 289 (processed 212) lb=15810561.03 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17165818.93, columns = 1575
#  -> Branch on pair-slot z(0,5,5) = 0.5000
#
# Node 290 (processed 213) lb=15810561.03 |B_T|=18 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16157259.37, columns = 1266
#  -> Branch on pair-slot z(1,5,5) = 0.5094
#
# Node 215 (processed 214) lb=15820077.43 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17636285.63, columns = 1934
#  -> Branch on pair-slot z(2,3,7) = 0.4657
#
# Node 216 (processed 215) lb=15820077.43 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17468698.07, columns = 1855
#  -> Branch on pair-slot z(3,5,9) = 0.4639
#
# Node 257 (processed 216) lb=15862961.64 |B_T|=10 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17178779.76, columns = 2906
#  -> Branch on pair-slot z(0,3,9) = 0.4824
#
# Node 258 (processed 217) lb=15862961.64 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16250212.01, columns = 2378
#  -> Branch on pair-slot z(3,4,3) = 0.4934
#
# Node 191 (processed 218) lb=15865338.96 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 18215502.38, columns = 1975
#  -> Branch on pair-slot z(0,2,2) = 0.5070
#
# Node 192 (processed 219) lb=15865338.96 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16675835.26, columns = 1679
#  -> Branch on pair-slot z(0,2,5) = 0.5205
#
# Node 281 (processed 220) lb=15876286.40 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16406538.52, columns = 2880
#  -> Branch on pair-slot z(0,4,6) = 0.5013
#
# Node 282 (processed 221) lb=15876286.40 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16278214.53, columns = 2465
#  -> Branch on pair-slot z(3,4,8) = 0.4895
#
# Node 309 (processed 222) lb=15882673.14 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16257191.64, columns = 2044
#  -> Branch on pair-slot z(0,5,8) = 0.5020
#
# Node 310 (processed 223) lb=15882673.14 |B_T|=16 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16222266.66, columns = 1859
#  -> Branch on pair-slot z(2,4,1) = 0.4859
#
# Node 373 (processed 224) lb=15907714.28 |B_T|=14 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16635572.27, columns = 3229
#  -> Branch on pair-slot z(0,1,3) = 0.4935
#
# Node 374 (processed 225) lb=15907714.28 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16994336.50, columns = 2625
#  -> Branch on pair-slot z(0,1,7) = 0.4727
#
# Node 189 (processed 226) lb=15913395.43 |B_T|=4 |B_S|=0 |R|=6
#  -> Node LP obj (lower bound) = 16815966.07, columns = 4703
#  -> Branch on pair-slot z(0,5,7) = 0.4831
#
# Node 190 (processed 227) lb=15913395.43 |B_T|=6 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 16583373.91, columns = 4246
#  -> Branch on pair-slot z(1,4,8) = 0.4985
#
# Node 231 (processed 228) lb=15925448.18 |B_T|=4 |B_S|=0 |R|=6
#  -> Node LP obj (lower bound) = 17131380.07, columns = 4425
#  -> Branch on pair-slot z(0,1,5) = 0.5132
#
# Node 232 (processed 229) lb=15925448.18 |B_T|=6 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 17040241.80, columns = 3744
#  -> Branch on pair-slot z(0,5,7) = 0.5042
#
# Node 293 (processed 230) lb=15929329.91 |B_T|=14 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 18775461.23, columns = 2282
#  -> Branch on pair-slot z(2,4,3) = 0.5036
#
# Node 294 (processed 231) lb=15929329.91 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17482130.04, columns = 2081
#  -> Branch on pair-slot z(1,3,4) = 0.5059
#
# Node 245 (processed 232) lb=15937241.81 |B_T|=8 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 17299786.46, columns = 4202
#  -> Branch on pair-slot z(0,1,0) = 0.4933
#
# Node 246 (processed 233) lb=15937241.81 |B_T|=10 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16748911.22, columns = 3862
#  -> Branch on pair-slot z(1,3,7) = 0.5000
#
# Node 203 (processed 234) lb=15946290.11 |B_T|=10 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17757408.62, columns = 1695
#  -> Branch on pair-slot z(0,5,2) = 0.4973
#
# Node 204 (processed 235) lb=15946290.11 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17242966.84, columns = 1586
#  -> Branch on pair-slot z(1,4,1) = 0.5092
#
# Node 301 (processed 236) lb=15947257.99 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16068806.01, columns = 1434
#  -> Branch on pair-slot z(2,4,8) = 0.4857
#
# Node 302 (processed 237) lb=15947257.99 |B_T|=16 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16657626.95, columns = 1200
#  -> Branch on pair-slot z(0,2,4) = 0.5145
#
# Node 129 (processed 238) lb=15956958.56 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17458922.12, columns = 1565
#  -> Branch on pair-slot z(0,2,1) = 0.4893
#
# Node 130 (processed 239) lb=15956958.56 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17070331.18, columns = 1427
#  -> Branch on pair-slot z(2,3,5) = 0.4857
#
# Node 127 (processed 240) lb=15958429.58 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17164415.37, columns = 1825
#  -> Branch on pair-slot z(3,5,0) = 0.5042
#
# Node 128 (processed 241) lb=15958429.58 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17320813.36, columns = 1751
#  -> Branch on pair-slot z(2,3,7) = 0.4995
#
# Node 385 (processed 242) lb=15969839.51 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16753735.14, columns = 3486
#  -> Branch on pair-slot z(4,5,1) = 0.4822
#
# Node 386 (processed 243) lb=15969839.51 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16390555.21, columns = 3356
#  -> Branch on pair-slot z(3,5,6) = 0.4732
#
# Node 47 (processed 244) lb=15972881.26 |B_T|=4 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16901670.30, columns = 1536
#  -> Branch on pair-slot z(0,2,3) = 0.5018
#
# Node 48 (processed 245) lb=15972881.26 |B_T|=6 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16475567.11, columns = 1231
#  -> Branch on pair-slot z(1,4,5) = 0.4936
#
# Node 163 (processed 246) lb=16024162.56 |B_T|=6 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 18558710.23, columns = 3966
#  -> Branch on pair-slot z(1,2,2) = 0.4815
#
# Node 164 (processed 247) lb=16024162.56 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 18729690.99, columns = 3472
#  -> Branch on pair-slot z(1,4,5) = 0.5109
#
# Node 217 (processed 248) lb=16027099.40 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16910517.35, columns = 1609
#  -> Branch on pair-slot z(0,4,9) = 0.5060
#
# Node 218 (processed 249) lb=16027099.40 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16566038.09, columns = 1436
#  -> Branch on pair-slot z(0,5,5) = 0.4973
#
# Node 329 (processed 250) lb=16031196.09 |B_T|=10 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16359187.17, columns = 4082
#  -> Branch on pair-slot z(0,1,7) = 0.5107
#
# Node 330 (processed 251) lb=16031196.09 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17394496.10, columns = 4087
#  -> Branch on pair-slot z(2,4,3) = 0.4788
#
# Node 219 (processed 252) lb=16037508.04 |B_T|=12 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17429269.14, columns = 1486
#  -> Branch on pair-slot z(4,5,1) = 0.4848
#
# Node 220 (processed 253) lb=16037508.04 |B_T|=14 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17355097.08, columns = 1449
#  -> Branch on pair-slot z(1,2,4) = 0.4817
#
# Node 471 (processed 254) lb=16068806.01 |B_T|=14 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 18373471.28, columns = 1482
#  -> Branch on pair-slot z(1,2,9) = 0.5137
#
# Node 472 (processed 255) lb=16068806.01 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17816377.29, columns = 1390
#  -> Branch on pair-slot z(0,3,0) = 0.4986
#
# Node 305 (processed 256) lb=16088281.15 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17732509.02, columns = 1090
#  -> Branch on pair-slot z(0,3,5) = 0.5036
#
# Node 306 (processed 257) lb=16088281.15 |B_T|=14 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 17653745.24, columns = 989
#  -> Branch on pair-slot z(0,3,5) = 0.4780
#
# Node 179 (processed 258) lb=16095474.57 |B_T|=6 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 17148886.46, columns = 3530
#  -> Branch on pair-slot z(1,4,2) = 0.5112
#
# Node 180 (processed 259) lb=16095474.57 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16825500.54, columns = 2759
#  -> Branch on pair-slot z(1,5,8) = 0.5011
#
# Node 107 (processed 260) lb=16117351.33 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 18196120.90, columns = 1581
#  -> Branch on pair-slot z(0,5,3) = 0.5083
#
# Node 108 (processed 261) lb=16117351.33 |B_T|=18 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16157206.83, columns = 1333
#  -> Branch on pair-slot z(0,3,2) = 0.5111
#
# Node 321 (processed 262) lb=16118284.80 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16984449.70, columns = 1876
#  -> Branch on pair-slot z(3,4,0) = 0.4956
#
# Node 322 (processed 263) lb=16118284.80 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16387002.43, columns = 1730
#  -> Branch on pair-slot z(0,3,9) = 0.4900
#
# Node 303 (processed 264) lb=16156645.81 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17423763.30, columns = 1160
#  -> Branch on pair-slot z(3,4,7) = 0.5089
#
# Node 304 (processed 265) lb=16156645.81 |B_T|=12 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 18459630.49, columns = 1066
#  -> Branch on pair-slot z(0,3,5) = 0.4775
#
# Node 521 (processed 266) lb=16157206.83 |B_T|=18 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 18394047.77, columns = 1367
#  -> Branch on pair-slot z(0,2,4) = 0.5062
#
# Node 522 (processed 267) lb=16157206.83 |B_T|=20 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 17463818.78, columns = 1054
#  -> Branch on pair-slot z(4,5,4) = 0.5165
#
# Node 425 (processed 268) lb=16157259.37 |B_T|=18 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17176160.77, columns = 1297
#  -> Branch on pair-slot z(3,5,3) = 0.5059
#
# Node 426 (processed 269) lb=16157259.37 |B_T|=20 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 17349476.53, columns = 1161
#  -> Branch on pair-slot z(0,5,0) = 0.5036
#
# Node 251 (processed 270) lb=16160522.27 |B_T|=8 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 16772845.50, columns = 2035
#  -> Branch on pair-slot z(0,4,9) = 0.4909
#
# Node 252 (processed 271) lb=16160522.27 |B_T|=10 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17743251.50, columns = 1874
#  -> Branch on pair-slot z(0,2,9) = 0.5011
#
# Node 141 (processed 272) lb=16167336.95 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17946474.29, columns = 1589
#  -> Branch on pair-slot z(1,5,4) = 0.5037
#
# Node 142 (processed 273) lb=16167336.95 |B_T|=18 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 15745812.71, columns = 2082
#  -> Branch on pair-slot z(1,2,7) = 0.5110
#
# Node 545 (processed 274) lb=15745812.71 |B_T|=18 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 19024327.98, columns = 2413
#  -> Branch on pair-slot z(2,3,4) = 0.4917
#
# Node 546 (processed 275) lb=15745812.71 |B_T|=20 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16668350.08, columns = 2002
#  -> Branch on pair-slot z(2,4,9) = 0.4855
#
# Node 243 (processed 276) lb=16168844.41 |B_T|=6 |B_S|=0 |R|=6
#  -> Node LP obj (lower bound) = 17863624.22, columns = 4293
#  -> Branch on pair-slot z(3,5,2) = 0.4998
#
# Node 244 (processed 277) lb=16168844.41 |B_T|=8 |B_S|=0 |R|=5
#  -> Node LP obj (lower bound) = 17104541.87, columns = 3951
#  -> Branch on pair-slot z(1,3,9) = 0.4770
#
# Node 139 (processed 278) lb=16172303.35 |B_T|=14 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17471554.72, columns = 1637
#  -> Branch on pair-slot z(0,4,3) = 0.4978
#
# Node 140 (processed 279) lb=16172303.35 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17595052.86, columns = 1623
#  -> Branch on pair-slot z(1,2,0) = 0.4948
#
# Node 247 (processed 280) lb=16189165.38 |B_T|=18 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17503238.16, columns = 1655
#  -> Branch on pair-slot z(1,3,6) = 0.5355
#
# Node 248 (processed 281) lb=16189165.38 |B_T|=20 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 17123190.24, columns = 1437
#  -> Branch on pair-slot z(3,4,7) = 0.4888
#
# Node 279 (processed 282) lb=16190596.15 |B_T|=6 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17248967.20, columns = 2756
#  -> Branch on pair-slot z(0,4,9) = 0.5044
#
# Node 280 (processed 283) lb=16190596.15 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16800391.93, columns = 2336
#  -> Branch on pair-slot z(1,4,2) = 0.4988
#
# Node 103 (processed 284) lb=16212880.77 |B_T|=8 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16432074.56, columns = 1294
#  -> Branch on pair-slot z(3,4,0) = 0.4657
#
# Node 104 (processed 285) lb=16212880.77 |B_T|=10 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 16986894.29, columns = 1231
#  -> Branch on pair-slot z(0,1,6) = 0.5595
#
# Node 211 (processed 286) lb=16212946.59 |B_T|=4 |B_S|=0 |R|=4
#  -> Node LP obj (lower bound) = 17532766.50, columns = 3012
#  -> Branch on pair-slot z(1,2,1) = 0.4987
#
# Node 212 (processed 287) lb=16212946.59 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 16795942.49, columns = 2963
#  -> Branch on pair-slot z(2,3,9) = 0.5014
#
# Node 445 (processed 288) lb=16222266.66 |B_T|=16 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17018355.87, columns = 1986
#  -> Branch on pair-slot z(1,4,2) = 0.5032
#
# Node 446 (processed 289) lb=16222266.66 |B_T|=18 |B_S|=0 |R|=1
#  -> Node LP obj (lower bound) = 16514533.15, columns = 1953
#  -> Branch on pair-slot z(0,1,0) = 0.4965
#
# Node 67 (processed 290) lb=16237740.49 |B_T|=6 |B_S|=0 |R|=3
#  -> Node LP obj (lower bound) = 17708629.26, columns = 1488
#  -> Branch on pair-slot z(1,3,5) = 0.4833
#
# Node 68 (processed 291) lb=16237740.49 |B_T|=8 |B_S|=0 |R|=2
#  -> Node LP obj (lower bound) = 17719430.95, columns = 1341
# ...
#  -> Branch on pair-slot z(3,4,9) = 0.6389
#
# Node 1026 (processed 516) lb=16027332.00 |B_T|=4 |B_S|=3 |R|=6
#  -> Node LP obj (lower bound) = 16026725.00, columns = 6150
#  -> Fallback branch on team ATL (x_1859=0.5000)
#
# Node 1031 (processed 517) lb=16026725.00 |B_T|=4 |B_S|=4 |R|=6
#  -> Node LP obj (lower bound) = 16026914.50, columns = 6154
#  -> Fallback branch on team MON (x_5108=0.5000)
#
# Node 1032 (processed 518) lb=16026725.00 |B_T|=4 |B_S|=4 |R|=6
#  -> Node LP obj (lower bound) = 16026725.00, columns = 6175
#  -> Fallback branch on team ATL (x_1859=0.5000)
#
# Node 1035 (processed 519) lb=16026725.00 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16026914.50, columns = 6197
#  -> Fallback branch on team MON (x_5108=0.5000)
#
# Node 1036 (processed 520) lb=16026725.00 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16026947.00, columns = 6180
#  -> Fallback branch on team ATL (x_6148=0.5000)
#
# Node 1033 (processed 521) lb=16026914.50 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16564533.23, columns = 6182
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1034 (processed 522) lb=16026914.50 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16027222.50, columns = 6157
#  -> Fallback branch on team MON (x_5107=0.5000)
#
# Node 1037 (processed 523) lb=16026914.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16359336.33, columns = 6274
#  -> Branch on pair-slot z(0,1,9) = 0.6667
#
# Node 1038 (processed 524) lb=16026914.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16027222.50, columns = 6196
#  -> Fallback branch on team MON (x_5107=0.5000)
#
# Node 1039 (processed 525) lb=16026947.00 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 17192547.15, columns = 6283
#  -> Branch on pair-slot z(3,4,9) = 0.6389
#
# Node 1040 (processed 526) lb=16026947.00 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16027136.50, columns = 6180
#  -> Fallback branch on team MON (x_5107=0.5000)
#
# Node 1051 (processed 527) lb=16027136.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16564908.92, columns = 6196
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1052 (processed 528) lb=16027136.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16027222.50, columns = 6182
#  -> Fallback branch on team MON (x_5106=0.5000)
#
# Node 1043 (processed 529) lb=16027222.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16526019.81, columns = 6211
#  -> Branch on pair-slot z(3,4,9) = 0.6750
#
# Node 1044 (processed 530) lb=16027222.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16945391.82, columns = 6172
#  -> Branch on pair-slot z(3,5,3) = 0.6667
#
# Node 1047 (processed 531) lb=16027222.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16526019.81, columns = 6254
#  -> Branch on pair-slot z(3,4,9) = 0.6750
#
# Node 1048 (processed 532) lb=16027222.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16944996.05, columns = 6212
#  -> Branch on pair-slot z(3,5,3) = 0.6701
#
# Node 1055 (processed 533) lb=16027222.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16565003.04, columns = 6206
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1056 (processed 534) lb=16027222.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16945325.71, columns = 6207
#  -> Branch on pair-slot z(3,5,3) = 0.6701
#
# Node 1027 (processed 535) lb=16027450.50 |B_T|=4 |B_S|=3 |R|=6
#  -> Node LP obj (lower bound) = 17192522.04, columns = 6210
#  -> Branch on pair-slot z(3,4,9) = 0.6389
#
# Node 1028 (processed 536) lb=16027450.50 |B_T|=4 |B_S|=3 |R|=6
#  -> Node LP obj (lower bound) = 16028048.00, columns = 6119
#  -> Fallback branch on team ATL (x_4678=0.5000)
#
# Node 969 (processed 537) lb=16027932.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 15026635.50, columns = 6940
#  -> Fallback branch on team ATL (x_6853=0.5000)
#
# Node 1073 (processed 538) lb=15026635.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16359767.00, columns = 7261
#  -> Branch on pair-slot z(0,1,9) = 0.6667
#
# Node 1074 (processed 539) lb=15026635.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16471394.89, columns = 7770
#  -> Branch on pair-slot z(0,2,4) = 0.7778
#
# Node 970 (processed 540) lb=16027932.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16028236.00, columns = 6823
#  -> Fallback branch on team ATL (x_5955=0.7500)
#
# Node 1071 (processed 541) lb=16028048.00 |B_T|=4 |B_S|=4 |R|=6
#  -> Node LP obj (lower bound) = 16026834.00, columns = 6127
#  -> Fallback branch on team ATL (x_6118=0.5000)
#
# Node 1081 (processed 542) lb=16026834.00 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16027356.50, columns = 6211
#  -> Fallback branch on team ATL (x_6174=0.3750)
#
# Node 1082 (processed 543) lb=16026834.00 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16027023.50, columns = 6192
#  -> Fallback branch on team MON (x_5108=0.5000)
#
# Node 1085 (processed 544) lb=16027023.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16565101.85, columns = 6235
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1086 (processed 545) lb=16027023.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16027109.50, columns = 6194
#  -> Fallback branch on team MON (x_5107=0.5000)
#
# Node 1089 (processed 546) lb=16027109.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16565169.50, columns = 6221
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1090 (processed 547) lb=16027109.50 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16405371.68, columns = 6317
#  -> Branch on pair-slot z(3,4,9) = 0.5608
#
# Node 1083 (processed 548) lb=16027356.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16028578.00, columns = 6210
#  -> Fallback branch on team ATL (x_6176=0.5000)
#
# Node 1084 (processed 549) lb=16027356.50 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16027498.62, columns = 6221
#  -> Fallback branch on team ATL (x_6173=0.3750)
#
# Node 1097 (processed 550) lb=16027498.62 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16028578.00, columns = 6235
#  -> Fallback branch on team ATL (x_3465=0.5000)
#
# Node 1098 (processed 551) lb=16027498.62 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16027904.00, columns = 6225
#  -> Fallback branch on team MON (x_5107=0.5000)
#
# Node 1101 (processed 552) lb=16027904.00 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16565588.69, columns = 6261
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1102 (processed 553) lb=16027904.00 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16027990.00, columns = 6228
#  -> Fallback branch on team MON (x_5106=0.5000)
#
# Node 1105 (processed 554) lb=16027990.00 |B_T|=4 |B_S|=9 |R|=6
#  -> Node LP obj (lower bound) = 16565608.08, columns = 6269
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1106 (processed 555) lb=16027990.00 |B_T|=4 |B_S|=9 |R|=6
#  -> Node LP obj (lower bound) = 16927105.36, columns = 6256
#  -> Branch on pair-slot z(3,5,3) = 0.6500
#
# Node 1072 (processed 556) lb=16028048.00 |B_T|=4 |B_S|=4 |R|=6
#  -> Node LP obj (lower bound) = 16027383.00, columns = 6149
#  -> Fallback branch on team MON (x_5109=0.5000)
#
# Node 1111 (processed 557) lb=16027383.00 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16564503.38, columns = 6208
#  -> Branch on pair-slot z(3,4,9) = 0.6923
#
# Node 1112 (processed 558) lb=16027383.00 |B_T|=4 |B_S|=5 |R|=6
#  -> Node LP obj (lower bound) = 16027469.00, columns = 6168
#  -> Fallback branch on team MON (x_5108=0.5000)
#
# Node 1115 (processed 559) lb=16027469.00 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16359598.17, columns = 6190
#  -> Branch on pair-slot z(0,1,9) = 0.6667
#
# Node 1116 (processed 560) lb=16027469.00 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16944779.51, columns = 6192
#  -> Branch on pair-slot z(3,5,3) = 0.6667
#
# Node 1079 (processed 561) lb=16028236.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16777222.50, columns = 7529
#  -> Branch on pair-slot z(0,4,3) = 0.6250
#
# Node 1080 (processed 562) lb=16028236.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 15027686.50, columns = 6972
#  -> Fallback branch on team ATL (x_6831=0.5000)
#
# Node 1123 (processed 563) lb=15027686.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16185261.58, columns = 7157
#  -> Branch on pair-slot z(0,1,9) = 0.8421
#
# Node 1124 (processed 564) lb=15027686.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 17008337.36, columns = 7328
#  -> Branch on pair-slot z(0,2,4) = 0.5460
#
# Node 979 (processed 565) lb=16028236.00 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 16777222.50, columns = 7299
#  -> Branch on pair-slot z(0,4,3) = 0.6250
#
# Node 980 (processed 566) lb=16028236.00 |B_T|=4 |B_S|=6 |R|=6
#  -> Node LP obj (lower bound) = 15027497.00, columns = 6798
#  -> Fallback branch on team ATL (x_6723=0.5000)
#
# Node 1131 (processed 567) lb=15027497.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 15027686.50, columns = 6887
#  -> Fallback branch on team ATL (x_6797=0.5000)
#
# Node 1132 (processed 568) lb=15027497.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16718722.06, columns = 7202
#  -> Branch on pair-slot z(3,4,9) = 0.7759
#
# Node 1133 (processed 569) lb=15027686.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16185261.58, columns = 7058
#  -> Branch on pair-slot z(0,1,9) = 0.8421
#
# Node 1134 (processed 570) lb=15027686.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16526890.00, columns = 7422
#  -> Branch on pair-slot z(0,2,4) = 0.5000
#
# Node 981 (processed 571) lb=16028236.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16777222.50, columns = 7558
#  -> Branch on pair-slot z(0,4,3) = 0.6250
#
# Node 982 (processed 572) lb=16028236.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 15027686.50, columns = 6976
#  -> Fallback branch on team ATL (x_6846=0.5000)
#
# Node 1143 (processed 573) lb=15027686.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16185261.58, columns = 7182
#  -> Branch on pair-slot z(0,1,9) = 0.8421
#
# Node 1144 (processed 574) lb=15027686.50 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 17026854.00, columns = 7417
#  -> Branch on pair-slot z(0,2,4) = 0.5000
#
# Node 1095 (processed 575) lb=16028578.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 17192688.01, columns = 6251
#  -> Branch on pair-slot z(3,4,9) = 0.6389
#
# Node 1096 (processed 576) lb=16028578.00 |B_T|=4 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16277901.75, columns = 6261
#  -> Branch on pair-slot z(0,1,3) = 0.2500
#
# Node 1099 (processed 577) lb=16028578.00 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16277996.50, columns = 6290
#  -> Branch on pair-slot z(0,1,5) = 0.7500
#
# Node 1100 (processed 578) lb=16028578.00 |B_T|=4 |B_S|=8 |R|=6
#  -> Node LP obj (lower bound) = 16901359.19, columns = 6417
#  -> Branch on pair-slot z(0,4,3) = 0.5000
#
# Node 1125 (processed 579) lb=16185261.58 |B_T|=4 |B_S|=8 |R|=7
#  -> Node LP obj (lower bound) = 16360717.17, columns = 7429
#  -> Branch on pair-slot z(0,4,8) = 0.1667
#
# Node 1126 (processed 580) lb=16185261.58 |B_T|=6 |B_S|=8 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1145 (processed 581) lb=16185261.58 |B_T|=4 |B_S|=8 |R|=7
#  -> Node LP obj (lower bound) = 16360717.17, columns = 7380
#  -> Branch on pair-slot z(3,5,8) = 0.1667
#
# Node 1146 (processed 582) lb=16185261.58 |B_T|=6 |B_S|=8 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1137 (processed 583) lb=16185261.58 |B_T|=4 |B_S|=8 |R|=7
#  -> Node LP obj (lower bound) = 16360717.17, columns = 7293
#  -> Branch on pair-slot z(0,4,3) = 0.8333
#
# Node 1138 (processed 584) lb=16185261.58 |B_T|=6 |B_S|=8 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1151 (processed 585) lb=16277901.75 |B_T|=4 |B_S|=7 |R|=7
# CG reached max iterations.
#  -> Node LP obj (lower bound) = 19024752.00, columns = 7385
#  -> Fallback branch on team ATL (x_3959=0.5000)
#
# Node 1152 (processed 586) lb=16277901.75 |B_T|=6 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16320942.71, columns = 6006
#  -> Branch on pair-slot z(0,1,0) = 0.2353
#
# Node 1153 (processed 587) lb=16277996.50 |B_T|=4 |B_S|=8 |R|=7
#  -> Node LP obj (lower bound) = 16359887.17, columns = 6294
#  -> Branch on pair-slot z(0,4,8) = 0.3333
#
# Node 1154 (processed 588) lb=16277996.50 |B_T|=6 |B_S|=8 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1165 (processed 589) lb=16320942.71 |B_T|=6 |B_S|=7 |R|=7
#  -> Node LP obj (lower bound) = 19025194.67, columns = 7224
#  -> Branch on pair-slot z(3,4,3) = 0.6667
#
# Node 1166 (processed 590) lb=16320942.71 |B_T|=8 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 16359697.67, columns = 5671
#  -> Branch on pair-slot z(3,4,5) = 0.6667
#
# Node 1045 (processed 591) lb=16359336.33 |B_T|=4 |B_S|=6 |R|=7
#  -> Node LP obj (lower bound) = 16466100.08, columns = 6301
#  -> Branch on pair-slot z(3,4,9) = 0.6800
#
# Node 1046 (processed 592) lb=16359336.33 |B_T|=6 |B_S|=6 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1117 (processed 593) lb=16359598.17 |B_T|=4 |B_S|=6 |R|=7
#  -> Node LP obj (lower bound) = 16480783.82, columns = 6219
#  -> Branch on pair-slot z(3,4,9) = 0.6818
#
# Node 1118 (processed 594) lb=16359598.17 |B_T|=6 |B_S|=6 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 965 (processed 595) lb=16359602.83 |B_T|=4 |B_S|=4 |R|=7
#  -> Node LP obj (lower bound) = 16526651.17, columns = 7378
#  -> Branch on pair-slot z(0,1,5) = 0.7500
#
# Node 966 (processed 596) lb=16359602.83 |B_T|=6 |B_S|=4 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1171 (processed 597) lb=16359697.67 |B_T|=8 |B_S|=7 |R|=7
#  -> Node LP obj (lower bound) = 16449599.88, columns = 5690
#  -> Branch on pair-slot z(3,4,9) = 0.8041
#
# Node 1172 (processed 598) lb=16359697.67 |B_T|=10 |B_S|=7 |R|=6
#  -> Node LP obj (lower bound) = 19027183.50, columns = 5159
#  -> Fallback branch on team ATL (x_3056=0.5000)
#
# Node 1075 (processed 599) lb=16359767.00 |B_T|=4 |B_S|=7 |R|=7
#  -> Node LP obj (lower bound) = 16526795.75, columns = 7628
#  -> Branch on pair-slot z(0,1,5) = 0.7500
#
# Node 1076 (processed 600) lb=16359767.00 |B_T|=6 |B_S|=7 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1021 (processed 601) lb=16359856.33 |B_T|=4 |B_S|=5 |R|=7
#  -> Node LP obj (lower bound) = 16526994.50, columns = 7314
#  -> Branch on pair-slot z(3,4,3) = 0.2500
#
# Node 1022 (processed 602) lb=16359856.33 |B_T|=6 |B_S|=5 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1167 (processed 603) lb=16359887.17 |B_T|=4 |B_S|=8 |R|=8
# CG reached max iterations.
#  -> Node LP obj (lower bound) = 19027183.50, columns = 7616
#  -> Fallback branch on team ATL (x_3913=0.5000)
#
# Node 1168 (processed 604) lb=16359887.17 |B_T|=6 |B_S|=8 |R|=7
#  -> Node LP obj (lower bound) = 16027240.50, columns = 6149
#  -> Fallback branch on team FLA (x_6078=0.5000)
#
# Node 1189 (processed 605) lb=16027240.50 |B_T|=6 |B_S|=9 |R|=7
#  -> Node LP obj (lower bound) = 16106895.54, columns = 6197
#  -> Branch on pair-slot z(3,4,9) = 0.7000
#
# Node 1190 (processed 606) lb=16027240.50 |B_T|=6 |B_S|=9 |R|=7
#  -> Node LP obj (lower bound) = 17027720.50, columns = 6812
#  -> Fallback branch on team ATL (x_5927=0.5000)
#
# Node 1191 (processed 607) lb=16106895.54 |B_T|=6 |B_S|=9 |R|=8
#  -> Node LP obj (lower bound) = 16527424.70, columns = 6210
#  -> Branch on pair-slot z(0,4,9) = 0.2000
#
# Node 1192 (processed 608) lb=16106895.54 |B_T|=8 |B_S|=9 |R|=7
#  -> Node LP obj (lower bound) = 17692722.33, columns = 5985
#  -> Branch on pair-slot z(0,1,9) = 0.3333
#
# Node 991 (processed 609) lb=16359933.00 |B_T|=4 |B_S|=6 |R|=7
#  -> Node LP obj (lower bound) = 16527253.88, columns = 7935
#  -> Branch on pair-slot z(3,4,5) = 0.7500
#
# Node 992 (processed 610) lb=16359933.00 |B_T|=6 |B_S|=6 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 973 (processed 611) lb=16360316.67 |B_T|=4 |B_S|=5 |R|=7
#  -> Node LP obj (lower bound) = 16526137.12, columns = 7467
#  -> Branch on pair-slot z(0,1,9) = 0.5000
#
# Node 974 (processed 612) lb=16360316.67 |B_T|=6 |B_S|=5 |R|=6
#  -> Node LP infeasible, prune.
#
# Node 1161 (processed 613) lb=16360717.17 |B_T|=4 |B_S|=8 |R|=8
#  -> Node LP obj (lower bound) = 16527546.75, columns = 7379
#  -> Branch on pair-slot z(0,1,5) = 0.7500
#
# Node 1162 (processed 614) lb=16360717.17 |B_T|=6 |B_S|=8 |R|=7
#  -> Node LP obj (lower bound) = 19885305.29, columns = 7219
#  -> Branch on pair-slot z(0,4,8) = 0.4946
#
# Node 1159 (processed 615) lb=16360717.17 |B_T|=4 |B_S|=8 |R|=8
